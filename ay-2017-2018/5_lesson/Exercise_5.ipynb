# %% [markdown]
# # Reconstruct the Dewey classification at the British Library
# We start as usual by prepraring everything to work with our csv file.
#  * we import the module 'csv'
#  * we create an empty dictionary, *listDewey*, that will include DDC numbers, types of topics and specific topics
#  * we open the csv file and we iterate over its rows
#
# In order to fill the dictionary, we group pairs of 'type of topic'/'topic' by each DDC number. Therefore the new dictionary, *dictDewey*, will store DDC numbers as keys, and a list of tuples - in the form *(type of topic , topic)* - as values.
#
# To fill the dictionary with only unique keys, we define an *if/else* statement while iterating over the rows of the csv file.
#
#  * If the DDC number has already been included as a key of the dictionary (and therefore it has a list as value, including at least a tuple *(type of topic , topic)*), append only the new tuples to the end of the list.
#  * Otherwhise, if the DDC number has not been included yet as a key, create a key/value pair, where the value is a list including the tuple *(type of topic , topic)*.

# %%
import csv 

dictDewey = {}

with open('topics.csv', 'r', errors='ignore') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:

        # 1. dewey classification: dewey numbers are unique keys; values are lists. 
        # if the dewey number already exists, append new tuples to the list, otherwise the list is just that value
        if row['Dewey classification'] in dictDewey:
            dictDewey[row['Dewey classification']].append((row['Type of topic'], row['Topic']))
        else:
            dictDewey[row['Dewey classification']] = [(row['Type of topic'], row['Topic'])]
dictDewey
# Out:
# {'': [('chronological term', '1997-2011'),
#   ('general term', 'Adventure stories--History and criticism'),
#   ('general term', 'Apocalyptic literature--History and criticism'),
#   ('general term', 'Authors--Great Britain--Biography'),
#   ('title', 'Bible--Study and teaching'),
#   ('general term', 'Books and reading'),
#   ('person', 'Brown, Dan, 1964-'),
#   ('person', 'Bulgakov, Mikhail, 1891-1940'),
#   ('person', 'Bulgakov, Mikhail, 1891-1940--Philosophy'),
#   ('general term', 'Characters and characteristics'),
#   ('general term', "Children's literature"),
#   ('general term', "Children's literature, English"),
#   ('general term',
#    "Children's literature, English--Germany--History and criticism"),
#   ('general term', "Children's literature, English--History and criticism"),
#   ('general term', "Children's literature, English--History and criticism"),
#   ('general term', "Children's literature--History and criticism"),
#   ('general term', "Children's literature--Marketing"),
#   ('general term', "Children's stories, English--Appreciation"),
#   ('general term', "Children's stories, English--Authorship"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--Study and teaching"),
#   ('general term',
#    "Children's stories--20th century--Translations into Burmese"),
#   ('general term', 'Children--Books and reading'),
#   ('general term', 'Children--Books and reading'),
#   ('general term', 'Children--Books and reading--English-speaking countries'),
#   ('general term', 'Children--Religious life'),
#   ('general term',
#    'Christianity and literature--Russkai︠a︡ pravoslavnai︠a︡ t︠s︡erkovʹ'),
#   ('general term', 'Christianity in literature'),
#   ('general term', 'Communication in literature'),
#   ('general term', 'Creative ability in children--Cross-cultural studies'),
#   ('general term', 'EDUCATION / Parent Participation'),
#   ('general term', 'EDUCATION / Students & Student Life'),
#   ('geographical term', 'England'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('general term', 'English language--Dictionaries--German'),
#   ('general term', 'English literature--Appreciation'),
#   ('general term', 'Ethics in literature'),
#   ('general term', 'Fan fiction'),
#   ('general term', 'Fan fiction--History and criticism'),
#   ('general term', 'Fantasy fiction, English--Appreciation'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--Study and teaching'),
#   ('general term', 'Fantasy fiction--History and criticism'),
#   ('general term', 'Fantasy in children--Cross-cultural studies'),
#   ('general term',
#    'Fantasy literature, English--Germany--History and criticism'),
#   ('general term', 'Fiction--20th century--Themes, motives etc'),
#   ('general term', 'Girls in literature'),
#   ('general term', 'Harry Potter (Fictitious character)'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films--History and criticism'),
#   ('general term', 'Harry Potter films--History and criticism'),
#   ('title', 'Harry Potter series (Rowling, J. K.)'),
#   ('title', 'Harry Potter series (Rowling, J. K.)'),
#   ('general term', 'Harry Potter'),
#   ('general term', 'Hermeneutics'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term', 'Homosexuality in motion pictures'),
#   ('general term', 'Imagination in children--Cross-cultural studies'),
#   ('general term', 'Juvenile Literature--Criticism--Child and Reading'),
#   ('person', 'Ködöböcz, József'),
#   ('general term', 'Literature and society'),
#   ('general term', 'Literature and society'),
#   ('general term', 'Literature--History and criticism'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic'),
#   ('general term', 'Magic--Dictionaries--English'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Religious aspects--Christianity'),
#   ('geographical term', 'Magyarorszâag'),
#   ('general term', 'Martyrs'),
#   ('general term', 'Mass media and children--Cross-cultural studies'),
#   ('general term', 'Mass media and literature'),
#   ('general term', 'Medicine, Magic, mystic, and spagiric'),
#   ('general term', 'Medicine--History'),
#   ('general term', 'Motion picture music--Excerpts, Arranged'),
#   ('organisation', 'National Library of Medicine (U.S.)--Exhibitions'),
#   ('person', 'Newman, John Henry, 1801-1890'),
#   ('general term', 'Nimbus'),
#   ('general term', 'Novelists, English--20th century--Biography'),
#   ('general term', 'Piano music, Arranged'),
#   ('general term', 'Popular instrumental music'),
#   ('general term', 'Potter'),
#   ('general term', 'Potter, Harry (Fictitious character)'),
#   ('general term',
#    'Potter, Harry (Fictitious character)--Miscellanea--Juvenile literature'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)--Congresses'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Criticism and interpretation'),
#   ('person', 'Potter, Harry, (Fictitious character)--Dictionaries--English'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Religious aspects'),
#   ('person', 'Potter, Harry, (Fictitious character)--Religious aspects'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Religious aspects--Christianity'),
#   ('general term', 'Psychoanalysis and literature'),
#   ('general term', 'Queer theory'),
#   ('general term', 'Reading interests'),
#   ('general term', 'Recorded accompaniments'),
#   ('general term', 'Religion and culture'),
#   ('general term', 'Religion in literature'),
#   ('general term', 'Role models--Cross-cultural studies'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K.--Appreciation--Russia (Federation)'),
#   ('person', 'Rowling, J. K.--Characters'),
#   ('person', 'Rowling, J. K.--Characters'),
#   ('person', 'Rowling, J. K.--Characters--Girls'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Miscellanea--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters--Women'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation--Congresses'),
#   ('person', 'Rowling, J. K.--Film adaptations--History and criticism'),
#   ('person', 'Rowling, J. K.--Influence'),
#   ('person', 'Rowling, J. K.--Literary style'),
#   ('person', 'Rowling, J. K.--Study and teaching'),
#   ('general term', 'Schools'),
#   ('general term', 'Schools--Juvenile fiction'),
#   ('general term', 'Schools--Juvenile fiction'),
#   ('general term', 'Self-perception in children--Cross-cultural studies'),
#   ('general term', 'Sex role in literature'),
#   ('general term', 'Success in literature'),
#   ('geographical term', 'Sâarospatak'),
#   ('general term', 'Theology'),
#   ('person', 'Tolkien, J. R. R. (John Ronald Reuel), 1892-1973'),
#   ('general term', 'Twilight saga films'),
#   ('general term', 'Ungdomsböcker--genusaspekter'),
#   ('general term', 'Universities and colleges'),
#   ('general term', 'Wizards in literature'),
#   ('general term', 'Wizards in literature'),
#   ('general term', 'Wizards in literature'),
#   ('general term', 'Wizards'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Women authors--Great Britain--Biography'),
#   ('general term', 'Women in literature'),
#   ('general term', 'Women novelists, English--20th century--Biography'),
#   ('general term', 'Young adult literature, American--History and criticism'),
#   ('general term', 'Young adult literature, American--Themes, motives'),
#   ('general term', 'Young adult literature, English'),
#   ('general term', 'Young adult literature, European--History and criticism'),
#   ('general term', 'Young adult literature, European--Themes, motives'),
#   ('general term',
#    'Young adult literature, Scandinavian--History and criticism'),
#   ('general term', 'Young adult literature, Scandinavian--Themes, motives'),
#   ('general term', 'nevelâestèortâenet'),
#   ('general term', 'pedagâogia'),
#   ('general term', 'pedagâogus'),
#   ('person', 'Булгаков, Михаил Афанасьевич, 1891-1940')],
#  '005.117': [('general term', 'COMPUTERS / Programming / Object Oriented'),
#   ('general term', 'Object-oriented programming (Computer science)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Rowling, J. K.--Characters'),
#   ('person', 'Rowling, J. K.--Themes, motives')],
#  '016.8239140809282': [('general term', 'Best books'),
#   ('general term', 'Children--Books and reading')],
#  '133 ; 823.914': [('general term', 'Archetype (Psychology)'),
#   ('general term', 'Archetypus'),
#   ('title', 'Harry Potter'),
#   ('general term', 'Mythologie'),
#   ('general term', 'Mythology'),
#   ('person', 'Rowling, J. K')],
#  '133.43': [('general term', 'Magic--Juvenile literature')],
#  '133.4309': [('general term', 'Wizards in literature'),
#   ('general term', 'Wizards--History')],
#  '133.430922': [('general term', 'Wizards in literature'),
#   ('general term', 'Wizards')],
#  '152.4': [('general term', 'Anger'),
#   ('general term', 'Anxiety--Popular works'),
#   ('general term', 'Depression, Mental--Popular works'),
#   ('general term', 'Grief')],
#  '155.937083': [('general term', 'Bereavement in adolescence'),
#   ('general term', 'Bereavement in children'),
#   ('general term', 'Characters and characteristics in literature'),
#   ('general term', 'Grief in adolescence'),
#   ('general term', 'Grief in children')],
#  '226.06': [('general term',
#    "Children's stories, English--History and criticism"),
#   ('general term', 'Children--Books and reading--English-speaking countries'),
#   ('general term', 'Christian fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('general term', 'Religion in literature'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Religion'),
#   ('general term', 'Spirituality in literature')],
#  '230': [('general term', 'Christianity and literature'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation')],
#  '259.23': [('general term', 'Church work with youth--Church of England'),
#   ('general term', 'Potter, Harry (Fictitious character)--Miscellanea')],
#  '261.513': [('general term', 'Occultism--Religious aspects--Christianity'),
#   ('person', 'Potter, Harry, (Fictitious character)')],
#  '261.58': [('general term', 'Christianity and culture'),
#   ('general term', 'Christianity and literature'),
#   ('general term',
#    'Fantasy fiction, English--Religious aspects--Christianity'),
#   ('general term', 'Fantasy literature--Religious aspects--Christianity'),
#   ('title', 'Harry Potter'),
#   ('general term', 'Katholische Kirche'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Pastoral theology'),
#   ('general term', 'Pastoraltheologie'),
#   ('general term', 'Pop-Kultur'),
#   ('general term', 'Popular culture--Religious aspects--Christianity'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Rowling, J. K.--Characters'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('general term', 'Rowling, J.K--Influence')],
#  '302.2244': [('general term', 'Children--Books and reading'),
#   ('general term', 'Children--Books and reading'),
#   ('general term', 'Literacy--Social aspects'),
#   ('general term', 'Literacy--Social aspects'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Rowling, J. K.--Influence'),
#   ('person', 'Rowling, J. K.--Influence')],
#  '302.23083': [('general term',
#    'Creative ability in children--Cross-cultural studies--Congresses'),
#   ('general term', 'Fantasy in children--Cross-cultural studies--Congresses'),
#   ('general term',
#    'Imagination in children--Cross-cultural studies--Congresses'),
#   ('general term',
#    'Mass media and children--Cross-cultural studies--Congresses'),
#   ('general term', 'Role models--Cross-cultural studies--Congresses'),
#   ('general term',
#    'Self-perception in children--Cross-cultural studies--Congresses')],
#  '305.235': [('general term', 'Mass media and youth--Social aspects'),
#   ('general term', 'Mass media and youth--Social aspects'),
#   ('general term', 'Popular culture'),
#   ('general term', 'Popular culture'),
#   ('general term', 'Youth--Social conditions'),
#   ('general term', 'Youth--Social conditions')],
#  '398.21': [('general term', 'Wizards')],
#  '500': [('general term', 'Magic'),
#   ('general term', 'Magic--Popular works'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('general term', 'Science--Popular works'),
#   ('general term', 'Science--Popular works')],
#  '641.5': [('general term', 'Cooking')],
#  '658.812': [('general term', 'Brand name products'),
#   ('general term', 'Branding (Marketing)'),
#   ('person', 'Potter, Harry, (Fictitious character)')],
#  '658.827': [('general term', 'Advertising--Brand name products'),
#   ('general term', 'Brand name products--Marketing'),
#   ('general term', 'Character merchandising'),
#   ('person', 'Potter, Harry, (Fictitious character)')],
#  '688.72': [('general term',
#    'LEGO toys--Design and construction--Juvenile literature'),
#   ('general term', 'LEGO toys--Juvenile literature'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile literature'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters')],
#  '709.04072': [('general term',
#    'Optical illusions in art--Juvenile literature'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Pictorial works--Juvenile literature')],
#  '741.4375': [('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Lift-the-flap books'),
#   ('general term', 'Pop-up books')],
#  '746.432041': [('general term', 'Knitting--Patterns'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter')],
#  '778.92': [('general term', 'Authors, English--Biography'),
#   ('general term', 'Authors, English--Portraits--Exhibitions'),
#   ('general term', "Children's literature, English")],
#  '783.242166': [('general term', 'Motion picture music--Excerpts, Arranged'),
#   ('general term', 'Piano music, Arranged'),
#   ('general term', 'Popular instrumental music')],
#  '786.21542': [('general term', 'Motion picture music'),
#   ('general term', 'Motion picture music--Excerpts, Arranged'),
#   ('general term', 'Motion picture music--Excerpts, Arranged'),
#   ('general term', 'Motion picture music--Excerpts--Piano scores'),
#   ('general term', 'Piano music, Arranged'),
#   ('general term', 'Piano music, Arranged'),
#   ('general term', 'Piano music, Arranged'),
#   ('general term', 'Popular music--2001-2010')],
#  '786.21556076': [('general term', 'Dance accompaniment music'),
#   ('general term', 'Motion picture music--Excerpts--Piano scores'),
#   ('general term', 'Piano music, Arranged')],
#  '788.32': [('organisation',
#    'Associated Board of the Royal Schools of Music (Great Britain)--Examinations'),
#   ('general term', 'Flute and piano music, Arranged--Scores and parts'),
#   ('general term', 'Flute and piano music--Scores and parts'),
#   ('general term', 'Flute music'),
#   ('general term', 'Flute--Great Britain--Examinations, questions, etc'),
#   ('general term', 'Recorded accompaniments (Flute)')],
#  '791': [('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films--History and criticism'),
#   ('general term', 'Philosophy in motion pictures'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K.--Themes, motives'),
#   ('general term', 'Themes, motives')],
#  '791.43': [('general term', 'Myth in literature'),
#   ('general term', 'Myth in motion pictures'),
#   ('general term', 'Popular culture and literature'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('general term', 'Star Wars films--History and criticism')],
#  '791.436557': [('geographical term', 'Great Britain--In motion pictures'),
#   ('general term', 'Schools in motion pictures')],
#  '791.4372': [('general term', 'Cinematography--Special effects'),
#   ('title',
#    'Harry Potter and the Deathly Hallows, part 1 (Motion picture)--Juvenile literature'),
#   ('title',
#    'Harry Potter and the Order of the Phoenix (Motion picture)--Miscellanea'),
#   ('title',
#    'Harry Potter and the Order of the Phoenix (Motion picture)--Pictorial works'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile films'),
#   ('general term', 'Magic in motion pictures'),
#   ('general term', 'Magic wands'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile films'),
#   ('general term', 'Stage props'),
#   ('general term', 'Wizards--Juvenile films')],
#  '791.4375': [('general term',
#    'Characters and characteristics in motion pictures'),
#   ('person', 'Dumbledore, Albus, (Fictitious character)--Juvenile literature'),
#   ('general term', 'Families in motion pictures'),
#   ('general term', 'Families'),
#   ('title',
#    'Fantastic beasts and where to find them (Motion picture)--Juvenile literature'),
#   ('title',
#    'Fantastic beasts and where to find them (Motion picture)--Juvenile literature'),
#   ('general term', 'Films'),
#   ('person', 'Granger, Hermione, (Fictitious character)--Juvenile literature'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Miscellanea'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile literature'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile literature'),
#   ('general term', 'Imaginary places'),
#   ('general term', 'Lift-the-flap books'),
#   ('general term', 'Lift-the-flap books'),
#   ('general term', 'Motion pictures'),
#   ('general term', 'Motion pictures--Art direction'),
#   ('general term', 'Motion pictures--Setting and scenery'),
#   ('general term', 'Motion pictures--United States--History--20th century'),
#   ('general term', 'Motion pictures--United States--History--20th century'),
#   ('general term', 'Motion pictures--United States--History--21st century'),
#   ('general term', 'Motion pictures--United States--History--21st century'),
#   ('general term', 'PERFORMING ARTS--Reference'),
#   ('person', 'Potter, Harry (Fictitious character)--Miscellanea'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Collectibles--Periodicals'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile literature'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile literature'),
#   ('person', 'Potter, Harry, (Fictitious character)--Periodicals'),
#   ('person', 'Potter, Harry, (Fictitious character)--Pictorial works'),
#   ('person', 'Potter, Harry, (Fictitious character)--Pictorial works'),
#   ('person', 'Rowling, J. K.--Characters'),
#   ('person', 'Rowling, J. K.--Characters'),
#   ('person',
#    'Rowling, J. K.--Characters--Albus Dumbledore--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter--Juvenile literature'),
#   ('person',
#    'Rowling, J. K.--Characters--Hermione Granger--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters--Ron Weasley--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Film adaptations'),
#   ('geographical term', 'United States'),
#   ('geographical term', 'Verenigde Staten'),
#   ('person', 'Weasley, Ron, (Fictitious character)--Juvenile literature')],
#  '791.4575': [('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('general term', 'Harry Potter films--Juvenile literature'),
#   ('person',
#    'Rowling, J. K.--Characters--Albus Dumbledore--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter--Juvenile literature'),
#   ('person',
#    'Rowling, J. K.--Characters--Hermione Granger--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Characters--Ron Weasley--Juvenile literature')],
#  '794.1': [('general term', 'Chess for children--Periodicals'),
#   ('general term', 'Chess sets--Periodicals'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Collectibles--Periodicals')],
#  '794.14': [('general term', 'Chess for children--Periodicals'),
#   ('general term', 'Chess sets--Periodicals'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Collectibles--Periodicals')],
#  '808.3': [('general term', 'Disability studies'),
#   ('general term', 'Narration (Rhetoric)'),
#   ('general term', 'Reading disability'),
#   ('general term', 'Sociology of disability')],
#  '809': [('general term',
#    'Children--Books and reading--France--History--Exhibitions')],
#  '809.3766': [('general term', 'Fantasy fiction--History and criticism'),
#   ('general term', 'Fantasy fiction--History and criticism'),
#   ('general term', 'Fiction--20th century--History and criticism')],
#  '809.38766': [('general term', 'Fantasy fiction--History and criticism'),
#   ('general term', 'Fantasy--Religious aspects--Christianity')],
#  '809.89282': [('general term', "Children's literature"),
#   ('general term', "Children's literature--History and criticism"),
#   ('general term', "Children's literature--History and criticism"),
#   ('general term', "Children's literature--History and criticism"),
#   ('general term', "Children's literature--History and criticism"),
#   ('general term', "Children's literature--History and criticism"),
#   ('general term', 'Children--Books and reading')],
#  '809.8928209045': [('general term',
#    "Children's literature, American--History and criticism"),
#   ('general term', "Children's literature--History and criticism")],
#  '816.540080351': [('general term', "Children's writings"),
#   ('general term', 'Letters'),
#   ('person', 'Potter, Harry, (Fictitious character)')],
#  '822.92': [('general term', 'Fantasy drama'),
#   ('general term', 'Fantasy drama'),
#   ('general term', 'Fantasy drama'),
#   ('general term', 'Fantasy drama'),
#   ('general term', 'Fantasy drama'),
#   ('general term', 'Fantasy drama'),
#   ('general term', 'Large type books'),
#   ('person', 'Potter, Harry, (Fictitious character)--Drama'),
#   ('person', 'Potter, Harry, (Fictitious character)--Drama'),
#   ('person', 'Potter, Harry, (Fictitious character)--Drama'),
#   ('person', 'Potter, Harry, (Fictitious character)--Drama'),
#   ('person', 'Potter, Harry, (Fictitious character)--Drama'),
#   ('person', 'Potter, Harry, (Fictitious character)--Drama'),
#   ('general term', 'Wizards--Drama'),
#   ('general term', 'Wizards--Drama'),
#   ('general term', 'Wizards--Drama'),
#   ('general term', 'Wizards--Drama'),
#   ('general term', 'Wizards--Drama'),
#   ('general term', 'Wizards--Drama')],
#  '823.9': [('general term', "Children's & teenage literature studies"),
#   ('general term', 'Cultural studies'),
#   ('general term', 'Feminist literary criticism--Periodicals'),
#   ('title', 'Harry Potter series (Rowling, J. K.)'),
#   ('general term',
#    'LITERARY CRITICISM--European--English, Irish, Scottish, Welsh'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Popular culture'),
#   ('person', 'Potter, Harry, (fiktiv gestalt)'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K, 1965-'),
#   ('person', 'Rowling, J. K.--Characters--Women--Periodicals'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation--Periodicals'),
#   ('person', 'Rowling, J. K.--Periodicals'),
#   ('general term', 'Women in literature--Periodicals')],
#  '823.914': [('general term', 'Adolescence in literature'),
#   ('general term', 'Alchemy--Juvenile fiction'),
#   ('person', 'Anelli, Melissa'),
#   ('general term', 'Animals, Mythical--Juvenile literature'),
#   ('general term', 'Animals, Mythical--Juvenile literature'),
#   ('general term', 'Animals, Mythical--Juvenile literature'),
#   ('general term', 'Animals, Mythical--Pictorial works--Juvenile literature'),
#   ('title', 'Bible--In literature'),
#   ('general term', 'Childhood in literature'),
#   ('general term', "Children's Literature"),
#   ('general term', "Children's literature studies: general"),
#   ('general term', "Children's literature, English--History and criticism"),
#   ('general term', "Children's literature, English--History and criticism"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term', "Children's stories, English"),
#   ('general term',
#    "Children's stories, English--20th century--History and criticism"),
#   ('general term',
#    "Children's stories, English--21st century--History and criticism"),
#   ('general term', "Children's stories, English--Appreciation"),
#   ('general term', "Children's stories, English--Appreciation"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term', "Children's stories, English--History and criticism"),
#   ('general term',
#    "Children's stories, English--History and criticism--Handbooks, manuals, etc"),
#   ('general term',
#    "Children's stories, English--History and criticism--Handbooks, manuals, etc"),
#   ('general term', "Children's stories--History and criticism"),
#   ('general term', "Children's stories--Psychological aspects"),
#   ('general term', 'Children--Books and reading'),
#   ('general term', 'Children--Books and reading'),
#   ('general term', 'Children--Books and reading'),
#   ('general term', 'Children--Books and reading--English-speaking countries'),
#   ('general term', 'Children--Books and reading--English-speaking countries'),
#   ('general term', 'Children--Books and reading--English-speaking countries'),
#   ('general term', 'Children--Books and reading--English-speaking countries'),
#   ('general term', 'Children--Books and reading--English-speaking countries'),
#   ('general term', 'Christianity and literature'),
#   ('general term', 'Classical literature--Influence'),
#   ('general term', 'Collectibles'),
#   ('general term', 'Courage in literature'),
#   ('general term', 'Creative teaching'),
#   ('general term', 'Creative teaching--Case studies'),
#   ('general term', 'Critical pedagogy--United States'),
#   ('general term', 'Cultural studies'),
#   ('general term', 'EDUCATION / Multicultural Education'),
#   ('general term', 'EDUCATION / Philosophy & Social Aspects'),
#   ('general term', 'EDUCATION / Teaching Methods & Materials / General'),
#   ('general term', 'Education and state--United States'),
#   ('geographical term', 'England--Fiction'),
#   ('general term', 'Fans (Persons)'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term', 'Fantasy fiction, English'),
#   ('general term',
#    'Fantasy fiction, English--20th century--History and criticism'),
#   ('general term',
#    'Fantasy fiction, English--21st century--History and criticism'),
#   ('general term', 'Fantasy fiction, English--Appreciation'),
#   ('general term', 'Fantasy fiction, English--Appreciation'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term', 'Fantasy fiction, English--History and criticism'),
#   ('general term',
#    'Fantasy fiction, English--History and criticism--Handbooks, manuals, etc'),
#   ('general term',
#    'Fantasy fiction, English--History and criticism--Handbooks, manuals, etc'),
#   ('general term',
#    'Fantasy fiction, English--Miscellanea--Juvenile literature'),
#   ('general term', 'Fantasy fiction--Handbooks, manuals, etc'),
#   ('general term', 'Fantasy literature, English--History and criticism'),
#   ('general term', 'Fantasy stories, English'),
#   ('general term', 'Fantasy stories, English'),
#   ('general term', 'Generation Y--Political activity'),
#   ('general term', 'Girls in literature'),
#   ('geographical term', 'Great Britain--Description and travel'),
#   ('general term', 'HISTORY / General'),
#   ('general term', 'Harry Potter films--Collectibles'),
#   ('general term', 'Heroes in literature'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Computer games'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile literature'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Miscellanea'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Miscellanea'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Pictorial works--Juvenile literature'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Pictorial works--Juvenile literature'),
#   ('general term', 'Identity (Philosophical concept) in literature'),
#   ('general term', 'Identity (Psychology) in literature'),
#   ('general term', 'Interdisciplinary studies'),
#   ('general term', 'Italian language materials'),
#   ('general term', 'JUVENILE NONFICTION / Literary Criticism & Collections'),
#   ('general term', 'LITERARY COLLECTIONS / English, Irish, Scottish, Welsh'),
#   ('general term', "LITERARY CRITICISM / Children's Literature"),
#   ('general term',
#    'LITERARY CRITICISM--European--English, Irish, Scottish, Welsh'),
#   ('general term', 'Law in literature'),
#   ('general term', 'Leadership in literature'),
#   ('title', 'Leaky cauldron'),
#   ('general term', 'Literary Criticism & Collections'),
#   ('general term', 'Literary landmarks--Great Britain'),
#   ('general term', 'Literary recreations--Juvenile literature'),
#   ('general term', 'Literary studies: fiction, novelists & prose writers'),
#   ('general term', 'Literature and history'),
#   ('general term', 'Literature and society'),
#   ('general term',
#    'Literature publishing--Great Britain--History--20th century'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
# ...
#   ('general term', 'Heroes in literature'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Magic in literature'),
#   ('general term', 'Masculinity in literature'),
#   ('general term', 'Mythology in literature'),
#   ('general term',
#    'Novelists, English--20th century--Biography--Juvenile literature'),
#   ('general term', 'Philosophy in literature'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Potter, Harry (Fictitious character)--Miscellanea'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)--Collectibles'),
#   ('person', 'Potter, Harry, (Fictitious character)--Congresses'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile literature'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile literature'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature'),
#   ('person',
#    'Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature'),
#   ('general term', 'Religion and literature'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K'),
#   ('person', 'Rowling, J. K.--Characters'),
#   ('person', 'Rowling, J. K.--Characters--Collectibles'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter'),
#   ('person', 'Rowling, J. K.--Characters--Harry Potter--Congresses'),
#   ('person', 'Rowling, J. K.--Characters--Miscellanea'),
#   ('person', 'Rowling, J. K.--Characters--Miscellanea--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation'),
#   ('person', 'Rowling, J. K.--Criticism and interpretation--Congresses'),
#   ('person', 'Rowling, J. K.--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Juvenile literature'),
#   ('person', 'Rowling, J. K.--Themes, motives'),
#   ('general term', 'Wizards in literature'),
#   ('general term', 'Wizards in literature'),
#   ('general term', 'Wizards in literature'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term',
#    'Women authors, English--21st century--Juvenile literature'),
#   ('general term',
#    'Women authors, English--21st century--Juvenile literature'),
#   ('general term',
#    'Women novelists, English--20th century--Biography--Juvenile literature')],
#  '828.91402': [('person',
#    'Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature')],
#  '828.9207': [('general term',
#    "Children's stories--Forecasting--Juvenile literature"),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile literature')],
#  '895.43': [('geographical term', 'England'),
#   ('geographical term', 'England'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('geographical term', 'England--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term',
#    'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction'),
#   ('general term', 'Magic'),
#   ('general term', 'Magic'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('general term', 'Magic--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('person', 'Potter, Harry, (Fictitious character)--Juvenile fiction'),
#   ('general term', 'Schools'),
#   ('general term', 'Schools'),
#   ('general term', 'Schools--Juvenile fiction'),
#   ('general term', 'Schools--Juvenile fiction'),
#   ('general term', 'Wizards'),
#   ('general term', 'Wizards'),
#   ('general term', 'Wizards--Juvenile fiction'),
#   ('general term', 'Wizards--Juvenile fiction')]}

# %% [markdown]
# So doing we get a dictionary where the keys are unique, but there are several repetitions in their values (i.e. many tuples are the repeated in the same list).
#
# We clean the lists of tuples iterating over the pairs key/value of the dictionary (by using dictDewey*.items()*). The values (i.e. the lists) are defined as sets, thus duplicate tuples are removed.
#
# Duplicate tuples are removed, but still, the first item of the tuple is repeated several times for each different topic with the same type. Then we group topics by types of topic by modifying the structure of the list in a **defaultdict**.
#  * we define an empty defaultdict for each pair DDC/list of *dictDewey*
#  * we iterate over each item of a tuple (*k*, *v*)
#  * such defaultict are defined as empty lists that will be filled with unique keys *k* (types of topics) and a list of topics *v* as values.
#
# This process groups all the topics by a common type of topic, i.e. all the values are grouped by a common key.
#
# Lastly, we substitute the original values in key/value pairs of *dictDewey* with such new structure. The result is a cleaned dictionary

# %%
import csv 
from collections import defaultdict

dictDewey = {}

with open('topics.csv', 'r', errors='ignore') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:

        # 1. dewey classification: dewey numbers are unique keys; values are lists. 
        # if the dewey number already exists, append new tuples to the list, otherwise the list is just that value
        if row['Dewey classification'] in dictDewey:
            dictDewey[row['Dewey classification']].append((row['Type of topic'], row['Topic']))
        else:
            dictDewey[row['Dewey classification']] = [(row['Type of topic'], row['Topic'])]

# clean lists in the dictionary of Dewey numbers
for dewey, values_list in sorted(dictDewey.items()):
    values_list =list(set(values_list)) # remove duplicate tuples: (type of topic, topic)

    d = defaultdict(list)
    for k, v in values_list: # group tuples by type of topic
        d[k].append(v)
        dictDewey[dewey] = d.items()

dictDewey
# Out:
# {'': dict_items([('organisation', ['National Library of Medicine (U.S.)--Exhibitions']), ('geographical term', ['England--Juvenile fiction', 'Sâarospatak', 'Magyarorszâag', 'England']), ('person', ['Potter, Harry, (Fictitious character)--Religious aspects--Christianity', 'Rowling, J. K.--Study and teaching', 'Rowling, J. K.--Characters--Miscellanea--Juvenile literature', 'Potter, Harry, (Fictitious character)--Religious aspects', 'Rowling, J. K.--Influence', 'Potter, Harry, (Fictitious character)--Criticism and interpretation', 'Булгаков, Михаил Афанасьевич, 1891-1940', 'Tolkien, J. R. R. (John Ronald Reuel), 1892-1973', 'Ködöböcz, József', 'Newman, John Henry, 1801-1890', 'Rowling, J. K.--Criticism and interpretation--Congresses', 'Potter, Harry, (Fictitious character)--Dictionaries--English', 'Bulgakov, Mikhail, 1891-1940', 'Potter, Harry, (Fictitious character)--Juvenile fiction', 'Rowling, J. K.--Criticism and interpretation', 'Rowling, J. K.--Characters', 'Rowling, J. K.--Literary style', 'Brown, Dan, 1964-', 'Rowling, J. K.--Characters--Girls', 'Rowling, J. K.--Characters--Harry Potter', 'Potter, Harry, (Fictitious character)--Congresses', 'Potter, Harry, (Fictitious character)', 'Rowling, J. K', 'Bulgakov, Mikhail, 1891-1940--Philosophy', 'Potter, Harry, (Fictitious character)--Fiction', 'Rowling, J. K.--Appreciation--Russia (Federation)', 'Rowling, J. K.--Film adaptations--History and criticism', 'Rowling, J. K.--Characters--Women']), ('title', ['Bible--Study and teaching', 'Harry Potter series (Rowling, J. K.)']), ('general term', ['Girls in literature', 'Characters and characteristics', 'Harry Potter (Fictitious character)', 'Fan fiction--History and criticism', 'Magic--Religious aspects--Christianity', 'Success in literature', "Children's literature", 'Fantasy fiction--History and criticism', 'Apocalyptic literature--History and criticism', 'Schools--Juvenile fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)', 'Christianity in literature', 'Imagination in children--Cross-cultural studies', 'Fantasy literature, English--Germany--History and criticism', 'Piano music, Arranged', 'Wizards--Fiction', "Children's stories, English--Authorship", 'Harry Potter films--History and criticism', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction', 'nevelâestèortâenet', 'Adventure stories--History and criticism', 'Potter', 'Fantasy in children--Cross-cultural studies', 'Children--Books and reading--English-speaking countries', 'pedagâogus', 'Potter, Harry (Fictitious character)--Miscellanea--Juvenile literature', "Children's literature--Marketing", 'Magic', "Children's literature, English", 'Young adult literature, Scandinavian--History and criticism', 'Creative ability in children--Cross-cultural studies', 'Homosexuality in motion pictures', 'Juvenile Literature--Criticism--Child and Reading', 'Role models--Cross-cultural studies', "Children's literature, English--History and criticism", 'Ungdomsböcker--genusaspekter', 'Young adult literature, European--History and criticism', 'Young adult literature, European--Themes, motives', 'Mass media and children--Cross-cultural studies', 'Wizards--Juvenile fiction', 'pedagâogia', 'Martyrs', 'Young adult literature, American--History and criticism', 'English literature--Appreciation', 'EDUCATION / Students & Student Life', 'Theology', 'Reading interests', 'Novelists, English--20th century--Biography', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction', "Children's stories, English--History and criticism", 'Religion and culture', 'Potter, Harry (Fictitious character)', 'Authors--Great Britain--Biography', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction', "Children's stories--20th century--Translations into Burmese", 'Fantasy fiction, English--History and criticism', 'Medicine, Magic, mystic, and spagiric', 'EDUCATION / Parent Participation', 'Medicine--History', 'Books and r ...
#  '005.117': dict_items([('general term', ['Object-oriented programming (Computer science)', 'COMPUTERS / Programming / Object Oriented']), ('person', ['Potter, Harry, (Fictitious character)', 'Rowling, J. K.--Themes, motives', 'Rowling, J. K.--Characters'])]),
#  '016.8239140809282': dict_items([('general term', ['Best books', 'Children--Books and reading'])]),
#  '133 ; 823.914': dict_items([('title', ['Harry Potter']), ('general term', ['Archetypus', 'Mythology', 'Archetype (Psychology)', 'Mythologie']), ('person', ['Rowling, J. K'])]),
#  '133.43': dict_items([('general term', ['Magic--Juvenile literature'])]),
#  '133.4309': dict_items([('general term', ['Wizards in literature', 'Wizards--History'])]),
#  '133.430922': dict_items([('general term', ['Wizards in literature', 'Wizards'])]),
#  '152.4': dict_items([('general term', ['Depression, Mental--Popular works', 'Grief', 'Anger', 'Anxiety--Popular works'])]),
#  '155.937083': dict_items([('general term', ['Characters and characteristics in literature', 'Grief in adolescence', 'Grief in children', 'Bereavement in children', 'Bereavement in adolescence'])]),
#  '226.06': dict_items([('general term', ['Religion in literature', 'Children--Books and reading--English-speaking countries', 'Christian fiction, English--History and criticism', 'Fantasy fiction, English--History and criticism', 'Spirituality in literature', "Children's stories, English--History and criticism"]), ('person', ['Rowling, J. K.--Religion', 'Rowling, J. K.--Characters--Harry Potter', 'Potter, Harry, (Fictitious character)'])]),
#  '230': dict_items([('general term', ['Christianity and literature']), ('person', ['Rowling, J. K.--Criticism and interpretation'])]),
#  '259.23': dict_items([('general term', ['Potter, Harry (Fictitious character)--Miscellanea', 'Church work with youth--Church of England'])]),
#  '261.513': dict_items([('general term', ['Occultism--Religious aspects--Christianity']), ('person', ['Potter, Harry, (Fictitious character)'])]),
#  '261.58': dict_items([('title', ['Harry Potter']), ('general term', ['Popular culture--Religious aspects--Christianity', 'Rowling, J.K--Influence', 'Magic in literature', 'Christianity and literature', 'Fantasy fiction, English--Religious aspects--Christianity', 'Christianity and culture', 'Katholische Kirche', 'Pop-Kultur', 'Pastoraltheologie', 'Fantasy literature--Religious aspects--Christianity', 'Pastoral theology']), ('person', ['Potter, Harry, (Fictitious character)', 'Rowling, J. K.--Criticism and interpretation', 'Rowling, J. K.--Characters'])]),
#  '302.2244': dict_items([('general term', ['Children--Books and reading', 'Literacy--Social aspects']), ('person', ['Potter, Harry, (Fictitious character)', 'Rowling, J. K.--Influence'])]),
#  '302.23083': dict_items([('general term', ['Role models--Cross-cultural studies--Congresses', 'Self-perception in children--Cross-cultural studies--Congresses', 'Creative ability in children--Cross-cultural studies--Congresses', 'Imagination in children--Cross-cultural studies--Congresses', 'Mass media and children--Cross-cultural studies--Congresses', 'Fantasy in children--Cross-cultural studies--Congresses'])]),
#  '305.235': dict_items([('general term', ['Mass media and youth--Social aspects', 'Youth--Social conditions', 'Popular culture'])]),
#  '398.21': dict_items([('general term', ['Wizards'])]),
#  '500': dict_items([('general term', ['Magic', 'Magic--Popular works', 'Science--Popular works']), ('person', ['Potter, Harry, (Fictitious character)'])]),
#  '641.5': dict_items([('general term', ['Cooking'])]),
#  '658.812': dict_items([('general term', ['Brand name products', 'Branding (Marketing)']), ('person', ['Potter, Harry, (Fictitious character)'])]),
#  '658.827': dict_items([('general term', ['Character merchandising', 'Advertising--Brand name products', 'Brand name products--Marketing']), ('person', ['Potter, Harry, (Fictitious character)'])]),
#  '688.72': dict_items([('general term', ['LEGO toys--Juvenile literature', 'LEGO toys--Design and construction--Juvenile literature']), ('person', ['Potter, Harry, (Fictitious character)--Juvenile literature', 'Rowling, J. K.--Characters'])]),
#  '709.04072': dict_items([('general term', ['Optical illusions in art--Juvenile literature']), ('person', ['Potter, Harry, (Fictitious character)--Pictorial works--Juvenile literature'])]),
#  '741.4375': dict_items([('general term', ['Pop-up books', 'Lift-the-flap books', 'Harry Potter films--Juvenile literature'])]),
#  '746.432041': dict_items([('general term', ['Knitting--Patterns']), ('person', ['Rowling, J. K.--Characters--Harry Potter'])]),
#  '778.92': dict_items([('general term', ['Authors, English--Portraits--Exhibitions', "Children's literature, English", 'Authors, English--Biography'])]),
#  '783.242166': dict_items([('general term', ['Piano music, Arranged', 'Popular instrumental music', 'Motion picture music--Excerpts, Arranged'])]),
#  '786.21542': dict_items([('general term', ['Motion picture music--Excerpts, Arranged', 'Popular music--2001-2010', 'Motion picture music--Excerpts--Piano scores', 'Piano music, Arranged', 'Motion picture music'])]),
#  '786.21556076': dict_items([('general term', ['Piano music, Arranged', 'Dance accompaniment music', 'Motion picture music--Excerpts--Piano scores'])]),
#  '788.32': dict_items([('organisation', ['Associated Board of the Royal Schools of Music (Great Britain)--Examinations']), ('general term', ['Flute--Great Britain--Examinations, questions, etc', 'Recorded accompaniments (Flute)', 'Flute and piano music, Arranged--Scores and parts', 'Flute music', 'Flute and piano music--Scores and parts'])]),
#  '791': dict_items([('general term', ['Themes, motives', 'Philosophy in motion pictures', 'Harry Potter films--History and criticism', 'Harry Potter films']), ('person', ['Rowling, J. K.--Themes, motives', 'Rowling, J. K'])]),
#  '791.43': dict_items([('general term', ['Popular culture and literature', 'Star Wars films--History and criticism', 'Myth in motion pictures', 'Myth in literature']), ('person', ['Rowling, J. K.--Characters--Harry Potter', 'Potter, Harry, (Fictitious character)'])]),
#  '791.436557': dict_items([('general term', ['Schools in motion pictures']), ('geographical term', ['Great Britain--In motion pictures'])]),
#  '791.4372': dict_items([('title', ['Harry Potter and the Order of the Phoenix (Motion picture)--Pictorial works', 'Harry Potter and the Deathly Hallows, part 1 (Motion picture)--Juvenile literature', 'Harry Potter and the Order of the Phoenix (Motion picture)--Miscellanea']), ('general term', ['Wizards--Juvenile films', 'Magic in motion pictures', 'Magic wands', 'Stage props', 'Cinematography--Special effects', 'Harry Potter films', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile films']), ('person', ['Potter, Harry, (Fictitious character)--Juvenile films'])]),
#  '791.4375': dict_items([('title', ['Fantastic beasts and where to find them (Motion picture)--Juvenile literature']), ('general term', ['Motion pictures--Art direction', 'Films', 'Harry Potter films--Juvenile literature', 'Motion pictures', 'Families', 'Lift-the-flap books', 'Harry Potter films', 'Imaginary places', 'Motion pictures--Setting and scenery', 'Motion pictures--United States--History--21st century', 'PERFORMING ARTS--Reference', 'Families in motion pictures', 'Harry Potter films--Miscellanea', 'Characters and characteristics in motion pictures', 'Motion pictures--United States--History--20th century', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile literature']), ('geographical term', ['Verenigde Staten', 'United States']), ('person', ['Potter, Harry, (Fictitious character)--Collectibles--Periodicals', 'Rowling, J. K.--Film adaptations', 'Rowling, J. K.--Characters--Albus Dumbledore--Juvenile literature', 'Potter, Harry, (Fictitious character)--Pictorial works', 'Rowling, J. K.--Characters--Ron Weasley--Juvenile literature', 'Potter, Harry, (Fictitious character)--Juvenile literature', 'Potter, Harry, (Fictitious character)', 'Potter, Harry, (Fictitious character)--Periodicals', 'Rowling, J. K.--Characters', 'Weasley, Ron, (Fictitious character)--Juvenile literature', 'Dumbledore, Albus, (Fictitious character)--Juvenile literature', 'Rowling, J. K.--Characters--Hermione Granger--Juvenile literature', 'Rowling, J. K.--Characters--Harry Potter--Juvenile literature', 'Rowling, J. K.--Characters--Juvenile literature', 'Granger, Hermione, (Fictitious character)--Juvenile literature', 'Potter, Harry (Fictitious character)--Miscellanea'])]),
#  '791.4575': dict_items([('general term', ['Harry Potter films--Juvenile literature']), ('person', ['Rowling, J. K.--Characters--Harry Potter--Juvenile literature', 'Rowling, J. K.--Characters--Ron Weasley--Juvenile literature', 'Rowling, J. K.--Characters--Albus Dumbledore--Juvenile literature', 'Rowling, J. K.--Characters--Hermione Granger--Juvenile literature'])]),
#  '794.1': dict_items([('general term', ['Chess for children--Periodicals', 'Chess sets--Periodicals']), ('person', ['Potter, Harry, (Fictitious character)--Collectibles--Periodicals'])]),
#  '794.14': dict_items([('general term', ['Chess for children--Periodicals', 'Chess sets--Periodicals']), ('person', ['Potter, Harry, (Fictitious character)--Collectibles--Periodicals'])]),
#  '808.3': dict_items([('general term', ['Reading disability', 'Disability studies', 'Sociology of disability', 'Narration (Rhetoric)'])]),
#  '809': dict_items([('general term', ['Children--Books and reading--France--History--Exhibitions'])]),
#  '809.3766': dict_items([('general term', ['Fiction--20th century--History and criticism', 'Fantasy fiction--History and criticism'])]),
#  '809.38766': dict_items([('general term', ['Fantasy fiction--History and criticism', 'Fantasy--Religious aspects--Christianity'])]),
#  '809.89282': dict_items([('general term', ["Children's literature", 'Children--Books and reading', "Children's literature--History and criticism"])]),
#  '809.8928209045': dict_items([('general term', ["Children's literature--History and criticism", "Children's literature, American--History and criticism"])]),
#  '816.540080351': dict_items([('general term', ['Letters', "Children's writings"]), ('person', ['Potter, Harry, (Fictitious character)'])]),
#  '822.92': dict_items([('general term', ['Fantasy drama', 'Large type books', 'Wizards--Drama']), ('person', ['Potter, Harry, (Fictitious character)--Drama'])]),
#  '823.9': dict_items([('title', ['Harry Potter series (Rowling, J. K.)']), ('general term', ['Cultural studies', 'Magic in literature', 'Women in literature--Periodicals', "Children's & teenage literature studies", 'Feminist literary criticism--Periodicals', 'LITERARY CRITICISM--European--English, Irish, Scottish, Welsh', 'Popular culture']), ('person', ['Rowling, J. K', 'Rowling, J. K.--Criticism and interpretation--Periodicals', 'Rowling, J. K.--Criticism and interpretation', 'Potter, Harry, (fiktiv gestalt)', 'Rowling, J. K.--Periodicals', 'Rowling, J. K, 1965-', 'Rowling, J. K.--Characters--Women--Periodicals'])]),
#  '823.914': dict_items([('organisation', ['Pottermore.com (Firm)']), ('general term', ['Girls in literature', 'Heroes in literature', 'Collectibles', 'Riddles in literature', "LITERARY CRITICISM / Children's Literature", 'Transfiguration (Spiritualism)--Juvenile fiction', 'Multicultural education--California--Case studies', 'Interdisciplinary studies', 'Potter, Harry (Fictitious character)--Juvenile fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)', 'Popular literature--Study and teaching--Case studies', 'Wizards--Juvenile literature', 'Italian language materials', 'Literature and history', 'Magic--Juvenile literature', 'Religion and literature', 'EDUCATION / Teaching Methods & Materials / General', 'Wizards--Fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction', 'Magic--Psychological aspects', 'Fantasy literature, English--History and criticism', 'Children--Books and reading--English-speaking countries', 'Magic in literature--Juvenile literature', 'Wizards in literature--Juvenile literature', 'Identity (Philosophical concept) in literature', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Computer games', 'Fantasy fiction, English--History and criticism--Handbooks, manuals, etc', 'Literary recreations--Juvenile literature', 'Young adults--Books and reading', "Children's stories--Psychological aspects", 'Symbolism in literature', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile literature', 'Racism in literature', 'Fantasy fiction, English--20th century--History and criticism', 'Magic wands--Specimens', "Children's literature, English--History and criticism", 'Wizards--Miscellanea', 'Magic--Miscellanea', 'POLITICAL SCIENCE / History & Theory', "Children's stories--History and criticism", 'Women novelists, English--20th century--Biography--Juvenile literature', 'Politics in literature', 'Mythology, Greek, in literature', 'Literature publishing--Great Britain--History--20th century', 'Harry Potter films--Collectibles', 'Mythology in literature', 'Novelists, English--20th century--Biography--Juvenile literature', 'EDUCATION / Multicultural Education', 'Fans (Persons)', 'Wizards--Juvenile fiction', 'POLITICAL SCIENCE / Political Ideologies / General', 'Creative teaching--Case studies', 'Fantasy fiction, English', "Children's Literature", 'Toy and movable books', 'Leadership in literature', 'Wizards--Pictorial works--Juvenile fiction', 'Novelists, English--20th century--Biography', 'Alchemy--Juvenile fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction', 'Magic--Fiction', "Children's stories, English--History and criticism", 'Literary Criticism & Collections', 'Classical literature--Influence', 'Cultural studies', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Miscellanea', "Children's stories, English", 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction', 'Fantasy fiction, English--History and criticism', "Children's stories, English--20th century--History and criticism", 'Law in literature', 'Potter, Harry (Fictitious character)--Miscellanea', "Children's literature studies: general", 'Fantasy fiction, English--21st century--History and criticism', 'Literary studies: fiction, novelists & prose writers', "Children's stories, English--21st century--History and criticism", 'Young adult fiction, English--Study and teaching', 'Potter, Harry (Fictional character)--Handbooks, manuals, etc', 'Literature and society', 'Generation Y--Political activity', 'EDUCATION / Philosophy & Social Aspects', 'Animals, Mythical--Juvenile literature', 'Children--Books and reading', 'Women in literature', 'JUVENILE NONFICTION / Literary Criticism & Collections', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Pictorial works--Juvenile literature', 'Fantasy fiction, English--Appreciation', ...
#  '823.92': dict_items([('general term', ['Magic in literature', "Children's stories, English", 'Heroes in literature', 'Fantasy fiction, English--History and criticism', 'Christian art and symbolism in literature', 'Potter, Harry (Fictitious character)--Miscellanea', 'Archetype (Psychology) in literature', 'Masculinity in literature', 'Harry Potter films--Juvenile literature', 'Women authors, English--21st century--Juvenile literature', 'Women novelists, English--20th century--Biography--Juvenile literature', 'Mythology in literature', 'Novelists, English--20th century--Biography--Juvenile literature', 'Potter, Harry (Fictitious character)--Juvenile fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)', 'Harry Potter films', 'Wizards in literature', 'Wizards--Juvenile fiction', 'Allusions in literature', 'Religion and literature', 'Wizards--Fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction', 'Fantasy fiction, English', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction', 'Harry Potter films--Miscellanea', 'Children--Books and reading--English-speaking countries', 'Philosophy in literature', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction', "Children's stories, English--History and criticism"]), ('person', ['Rowling, J. K.--Characters--Collectibles', 'Rowling, J. K.--Themes, motives', 'Rowling, J. K.--Characters--Harry Potter', 'Potter, Harry, (Fictitious character)--Congresses', 'Potter, Harry, (Fictitious character)--Collectibles', 'Rowling, J. K.--Characters--Harry Potter--Congresses', 'Potter, Harry, (Fictitious character)--Juvenile literature', 'Potter, Harry, (Fictitious character)', 'Rowling, J. K.--Characters', 'Rowling, J. K.--Criticism and interpretation--Congresses', 'Rowling, J. K.--Juvenile literature', 'Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature', 'Rowling, J. K', 'Rowling, J. K.--Characters--Miscellanea--Juvenile literature', 'Potter, Harry, (Fictitious character)--Fiction', 'Rowling, J. K.--Characters--Miscellanea', 'Potter, Harry, (Fictitious character)--Juvenile fiction', 'Rowling, J. K.--Criticism and interpretation'])]),
#  '828.91402': dict_items([('person', ['Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature'])]),
#  '828.9207': dict_items([('general term', ["Children's stories--Forecasting--Juvenile literature"]), ('person', ['Potter, Harry, (Fictitious character)--Juvenile literature'])]),
#  '895.43': dict_items([('general term', ['Wizards', 'Magic--Juvenile fiction', 'Schools', 'Schools--Juvenile fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction', 'Hogwarts School of Witchcraft and Wizardry (Imaginary organization)', 'Magic', 'Wizards--Juvenile fiction']), ('geographical term', ['England--Juvenile fiction', 'England']), ('person', ['Potter, Harry, (Fictitious character)--Juvenile fiction', 'Potter, Harry, (Fictitious character)'])])}

# %% [markdown]
# We print in a pretty way our data by iterating over the new structure and we build a bullet list.

# %%
# print a list of dewey numbers, types of topics and topics
for x,y in sorted(dictDewey.items()): # sort by dewey number
    print(x, ':')
    for w, z in y:
        print('	-', w+ ':')
        for o in z:
            print('		-', o)
# Out:
#  :
# 	- organisation:
# 		- National Library of Medicine (U.S.)--Exhibitions
# 	- geographical term:
# 		- England--Juvenile fiction
# 		- Sâarospatak
# 		- Magyarorszâag
# 		- England
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Religious aspects--Christianity
# 		- Rowling, J. K.--Study and teaching
# 		- Rowling, J. K.--Characters--Miscellanea--Juvenile literature
# 		- Potter, Harry, (Fictitious character)--Religious aspects
# 		- Rowling, J. K.--Influence
# 		- Potter, Harry, (Fictitious character)--Criticism and interpretation
# 		- Булгаков, Михаил Афанасьевич, 1891-1940
# 		- Tolkien, J. R. R. (John Ronald Reuel), 1892-1973
# 		- Ködöböcz, József
# 		- Newman, John Henry, 1801-1890
# 		- Rowling, J. K.--Criticism and interpretation--Congresses
# 		- Potter, Harry, (Fictitious character)--Dictionaries--English
# 		- Bulgakov, Mikhail, 1891-1940
# 		- Potter, Harry, (Fictitious character)--Juvenile fiction
# 		- Rowling, J. K.--Criticism and interpretation
# 		- Rowling, J. K.--Characters
# 		- Rowling, J. K.--Literary style
# 		- Brown, Dan, 1964-
# 		- Rowling, J. K.--Characters--Girls
# 		- Rowling, J. K.--Characters--Harry Potter
# 		- Potter, Harry, (Fictitious character)--Congresses
# 		- Potter, Harry, (Fictitious character)
# 		- Rowling, J. K
# 		- Bulgakov, Mikhail, 1891-1940--Philosophy
# 		- Potter, Harry, (Fictitious character)--Fiction
# 		- Rowling, J. K.--Appreciation--Russia (Federation)
# 		- Rowling, J. K.--Film adaptations--History and criticism
# 		- Rowling, J. K.--Characters--Women
# 	- title:
# 		- Bible--Study and teaching
# 		- Harry Potter series (Rowling, J. K.)
# 	- general term:
# 		- Girls in literature
# 		- Characters and characteristics
# 		- Harry Potter (Fictitious character)
# 		- Fan fiction--History and criticism
# 		- Magic--Religious aspects--Christianity
# 		- Success in literature
# 		- Children's literature
# 		- Fantasy fiction--History and criticism
# 		- Apocalyptic literature--History and criticism
# 		- Schools--Juvenile fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)
# 		- Christianity in literature
# 		- Imagination in children--Cross-cultural studies
# 		- Fantasy literature, English--Germany--History and criticism
# 		- Piano music, Arranged
# 		- Wizards--Fiction
# 		- Children's stories, English--Authorship
# 		- Harry Potter films--History and criticism
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction
# 		- nevelâestèortâenet
# 		- Adventure stories--History and criticism
# 		- Potter
# 		- Fantasy in children--Cross-cultural studies
# 		- Children--Books and reading--English-speaking countries
# 		- pedagâogus
# 		- Potter, Harry (Fictitious character)--Miscellanea--Juvenile literature
# 		- Children's literature--Marketing
# 		- Magic
# 		- Children's literature, English
# 		- Young adult literature, Scandinavian--History and criticism
# 		- Creative ability in children--Cross-cultural studies
# 		- Homosexuality in motion pictures
# 		- Juvenile Literature--Criticism--Child and Reading
# 		- Role models--Cross-cultural studies
# 		- Children's literature, English--History and criticism
# 		- Ungdomsböcker--genusaspekter
# 		- Young adult literature, European--History and criticism
# 		- Young adult literature, European--Themes, motives
# 		- Mass media and children--Cross-cultural studies
# 		- Wizards--Juvenile fiction
# 		- pedagâogia
# 		- Martyrs
# 		- Young adult literature, American--History and criticism
# 		- English literature--Appreciation
# 		- EDUCATION / Students & Student Life
# 		- Theology
# 		- Reading interests
# 		- Novelists, English--20th century--Biography
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction
# 		- Children's stories, English--History and criticism
# 		- Religion and culture
# 		- Potter, Harry (Fictitious character)
# 		- Authors--Great Britain--Biography
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction
# 		- Children's stories--20th century--Translations into Burmese
# 		- Fantasy fiction, English--History and criticism
# 		- Medicine, Magic, mystic, and spagiric
# 		- EDUCATION / Parent Participation
# 		- Medicine--History
# 		- Books and reading
# 		- Sex role in literature
# 		- Schools
# 		- Literature and society
# 		- Universities and colleges
# 		- Religion in literature
# 		- Queer theory
# 		- Twilight saga films
# 		- Popular instrumental music
# 		- Christianity and literature--Russkai︠a︡ pravoslavnai︠a︡ t︠s︡erkovʹ
# 		- Fantasy fiction, English--Study and teaching
# 		- Young adult literature, American--Themes, motives
# 		- Children--Books and reading
# 		- Women in literature
# 		- Young adult literature, English
# 		- Hermeneutics
# 		- Women authors--Great Britain--Biography
# 		- Fantasy fiction, English--Appreciation
# 		- Nimbus
# 		- Ethics in literature
# 		- English language--Dictionaries--German
# 		- Young adult literature, Scandinavian--Themes, motives
# 		- Children's stories, English--Study and teaching
# 		- Psychoanalysis and literature
# 		- Harry Potter
# 		- Fan fiction
# 		- Motion picture music--Excerpts, Arranged
# 		- Self-perception in children--Cross-cultural studies
# 		- Magic in literature
# 		- Mass media and literature
# 		- Wizards
# 		- Magic--Juvenile fiction
# 		- Children's stories, English--Appreciation
# 		- Communication in literature
# 		- Harry Potter films
# 		- Wizards in literature
# 		- Children's literature--History and criticism
# 		- Magic--Dictionaries--English
# 		- Children's literature, English--Germany--History and criticism
# 		- Women novelists, English--20th century--Biography
# 		- Recorded accompaniments
# 		- Literature--History and criticism
# 		- Fiction--20th century--Themes, motives etc
# 		- Children--Religious life
# 	- chronological term:
# 		- 1997-2011
# 005.117 :
# 	- general term:
# 		- Object-oriented programming (Computer science)
# 		- COMPUTERS / Programming / Object Oriented
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 		- Rowling, J. K.--Themes, motives
# 		- Rowling, J. K.--Characters
# 016.8239140809282 :
# 	- general term:
# 		- Best books
# 		- Children--Books and reading
# 133 ; 823.914 :
# 	- title:
# 		- Harry Potter
# 	- general term:
# 		- Archetypus
# 		- Mythology
# 		- Archetype (Psychology)
# 		- Mythologie
# 	- person:
# 		- Rowling, J. K
# 133.43 :
# 	- general term:
# 		- Magic--Juvenile literature
# 133.4309 :
# 	- general term:
# 		- Wizards in literature
# 		- Wizards--History
# 133.430922 :
# 	- general term:
# 		- Wizards in literature
# 		- Wizards
# 152.4 :
# 	- general term:
# 		- Depression, Mental--Popular works
# 		- Grief
# 		- Anger
# 		- Anxiety--Popular works
# 155.937083 :
# 	- general term:
# 		- Characters and characteristics in literature
# 		- Grief in adolescence
# 		- Grief in children
# 		- Bereavement in children
# 		- Bereavement in adolescence
# 226.06 :
# 	- general term:
# 		- Religion in literature
# 		- Children--Books and reading--English-speaking countries
# 		- Christian fiction, English--History and criticism
# 		- Fantasy fiction, English--History and criticism
# 		- Spirituality in literature
# 		- Children's stories, English--History and criticism
# 	- person:
# 		- Rowling, J. K.--Religion
# 		- Rowling, J. K.--Characters--Harry Potter
# 		- Potter, Harry, (Fictitious character)
# 230 :
# 	- general term:
# 		- Christianity and literature
# 	- person:
# 		- Rowling, J. K.--Criticism and interpretation
# 259.23 :
# 	- general term:
# 		- Potter, Harry (Fictitious character)--Miscellanea
# 		- Church work with youth--Church of England
# 261.513 :
# 	- general term:
# 		- Occultism--Religious aspects--Christianity
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 261.58 :
# 	- title:
# 		- Harry Potter
# 	- general term:
# 		- Popular culture--Religious aspects--Christianity
# 		- Rowling, J.K--Influence
# 		- Magic in literature
# 		- Christianity and literature
# 		- Fantasy fiction, English--Religious aspects--Christianity
# 		- Christianity and culture
# 		- Katholische Kirche
# 		- Pop-Kultur
# 		- Pastoraltheologie
# 		- Fantasy literature--Religious aspects--Christianity
# 		- Pastoral theology
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 		- Rowling, J. K.--Criticism and interpretation
# 		- Rowling, J. K.--Characters
# 302.2244 :
# 	- general term:
# 		- Children--Books and reading
# 		- Literacy--Social aspects
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 		- Rowling, J. K.--Influence
# 302.23083 :
# 	- general term:
# 		- Role models--Cross-cultural studies--Congresses
# 		- Self-perception in children--Cross-cultural studies--Congresses
# 		- Creative ability in children--Cross-cultural studies--Congresses
# 		- Imagination in children--Cross-cultural studies--Congresses
# 		- Mass media and children--Cross-cultural studies--Congresses
# 		- Fantasy in children--Cross-cultural studies--Congresses
# 305.235 :
# 	- general term:
# 		- Mass media and youth--Social aspects
# 		- Youth--Social conditions
# 		- Popular culture
# 398.21 :
# 	- general term:
# 		- Wizards
# 500 :
# 	- general term:
# 		- Magic
# 		- Magic--Popular works
# 		- Science--Popular works
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 641.5 :
# 	- general term:
# 		- Cooking
# 658.812 :
# 	- general term:
# 		- Brand name products
# 		- Branding (Marketing)
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 658.827 :
# 	- general term:
# 		- Character merchandising
# 		- Advertising--Brand name products
# 		- Brand name products--Marketing
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 688.72 :
# 	- general term:
# 		- LEGO toys--Juvenile literature
# 		- LEGO toys--Design and construction--Juvenile literature
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Juvenile literature
# 		- Rowling, J. K.--Characters
# 709.04072 :
# 	- general term:
# 		- Optical illusions in art--Juvenile literature
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Pictorial works--Juvenile literature
# 741.4375 :
# 	- general term:
# 		- Pop-up books
# 		- Lift-the-flap books
# 		- Harry Potter films--Juvenile literature
# 746.432041 :
# 	- general term:
# 		- Knitting--Patterns
# 	- person:
# 		- Rowling, J. K.--Characters--Harry Potter
# 778.92 :
# 	- general term:
# 		- Authors, English--Portraits--Exhibitions
# 		- Children's literature, English
# 		- Authors, English--Biography
# 783.242166 :
# 	- general term:
# 		- Piano music, Arranged
# 		- Popular instrumental music
# 		- Motion picture music--Excerpts, Arranged
# 786.21542 :
# 	- general term:
# 		- Motion picture music--Excerpts, Arranged
# 		- Popular music--2001-2010
# 		- Motion picture music--Excerpts--Piano scores
# 		- Piano music, Arranged
# 		- Motion picture music
# 786.21556076 :
# 	- general term:
# 		- Piano music, Arranged
# 		- Dance accompaniment music
# 		- Motion picture music--Excerpts--Piano scores
# 788.32 :
# 	- organisation:
# 		- Associated Board of the Royal Schools of Music (Great Britain)--Examinations
# 	- general term:
# 		- Flute--Great Britain--Examinations, questions, etc
# 		- Recorded accompaniments (Flute)
# 		- Flute and piano music, Arranged--Scores and parts
# 		- Flute music
# 		- Flute and piano music--Scores and parts
# 791 :
# 	- general term:
# 		- Themes, motives
# 		- Philosophy in motion pictures
# 		- Harry Potter films--History and criticism
# 		- Harry Potter films
# 	- person:
# 		- Rowling, J. K.--Themes, motives
# 		- Rowling, J. K
# 791.43 :
# 	- general term:
# 		- Popular culture and literature
# 		- Star Wars films--History and criticism
# 		- Myth in motion pictures
# 		- Myth in literature
# 	- person:
# 		- Rowling, J. K.--Characters--Harry Potter
# 		- Potter, Harry, (Fictitious character)
# 791.436557 :
# 	- general term:
# 		- Schools in motion pictures
# 	- geographical term:
# 		- Great Britain--In motion pictures
# 791.4372 :
# 	- title:
# 		- Harry Potter and the Order of the Phoenix (Motion picture)--Pictorial works
# 		- Harry Potter and the Deathly Hallows, part 1 (Motion picture)--Juvenile literature
# 		- Harry Potter and the Order of the Phoenix (Motion picture)--Miscellanea
# 	- general term:
# 		- Wizards--Juvenile films
# 		- Magic in motion pictures
# 		- Magic wands
# 		- Stage props
# 		- Cinematography--Special effects
# 		- Harry Potter films
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile films
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Juvenile films
# 791.4375 :
# 	- title:
# 		- Fantastic beasts and where to find them (Motion picture)--Juvenile literature
# 	- general term:
# 		- Motion pictures--Art direction
# 		- Films
# 		- Harry Potter films--Juvenile literature
# 		- Motion pictures
# 		- Families
# 		- Lift-the-flap books
# 		- Harry Potter films
# 		- Imaginary places
# 		- Motion pictures--Setting and scenery
# 		- Motion pictures--United States--History--21st century
# 		- PERFORMING ARTS--Reference
# 		- Families in motion pictures
# 		- Harry Potter films--Miscellanea
# 		- Characters and characteristics in motion pictures
# 		- Motion pictures--United States--History--20th century
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile literature
# 	- geographical term:
# 		- Verenigde Staten
# 		- United States
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Collectibles--Periodicals
# 		- Rowling, J. K.--Film adaptations
# 		- Rowling, J. K.--Characters--Albus Dumbledore--Juvenile literature
# 		- Potter, Harry, (Fictitious character)--Pictorial works
# 		- Rowling, J. K.--Characters--Ron Weasley--Juvenile literature
# 		- Potter, Harry, (Fictitious character)--Juvenile literature
# 		- Potter, Harry, (Fictitious character)
# 		- Potter, Harry, (Fictitious character)--Periodicals
# 		- Rowling, J. K.--Characters
# 		- Weasley, Ron, (Fictitious character)--Juvenile literature
# 		- Dumbledore, Albus, (Fictitious character)--Juvenile literature
# 		- Rowling, J. K.--Characters--Hermione Granger--Juvenile literature
# 		- Rowling, J. K.--Characters--Harry Potter--Juvenile literature
# 		- Rowling, J. K.--Characters--Juvenile literature
# 		- Granger, Hermione, (Fictitious character)--Juvenile literature
# 		- Potter, Harry (Fictitious character)--Miscellanea
# 791.4575 :
# 	- general term:
# 		- Harry Potter films--Juvenile literature
# 	- person:
# 		- Rowling, J. K.--Characters--Harry Potter--Juvenile literature
# 		- Rowling, J. K.--Characters--Ron Weasley--Juvenile literature
# 		- Rowling, J. K.--Characters--Albus Dumbledore--Juvenile literature
# 		- Rowling, J. K.--Characters--Hermione Granger--Juvenile literature
# 794.1 :
# 	- general term:
# 		- Chess for children--Periodicals
# 		- Chess sets--Periodicals
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Collectibles--Periodicals
# 794.14 :
# 	- general term:
# 		- Chess for children--Periodicals
# 		- Chess sets--Periodicals
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Collectibles--Periodicals
# 808.3 :
# 	- general term:
# 		- Reading disability
# 		- Disability studies
# 		- Sociology of disability
# 		- Narration (Rhetoric)
# 809 :
# 	- general term:
# 		- Children--Books and reading--France--History--Exhibitions
# 809.3766 :
# 	- general term:
# 		- Fiction--20th century--History and criticism
# 		- Fantasy fiction--History and criticism
# 809.38766 :
# 	- general term:
# 		- Fantasy fiction--History and criticism
# 		- Fantasy--Religious aspects--Christianity
# 809.89282 :
# 	- general term:
# 		- Children's literature
# 		- Children--Books and reading
# 		- Children's literature--History and criticism
# 809.8928209045 :
# 	- general term:
# 		- Children's literature--History and criticism
# 		- Children's literature, American--History and criticism
# 816.540080351 :
# 	- general term:
# 		- Letters
# 		- Children's writings
# 	- person:
# 		- Potter, Harry, (Fictitious character)
# 822.92 :
# 	- general term:
# 		- Fantasy drama
# 		- Large type books
# 		- Wizards--Drama
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Drama
# 823.9 :
# 	- title:
# 		- Harry Potter series (Rowling, J. K.)
# 	- general term:
# 		- Cultural studies
# 		- Magic in literature
# 		- Women in literature--Periodicals
# 		- Children's & teenage literature studies
# 		- Feminist literary criticism--Periodicals
# 		- LITERARY CRITICISM--European--English, Irish, Scottish, Welsh
# 		- Popular culture
# 	- person:
# 		- Rowling, J. K
# 		- Rowling, J. K.--Criticism and interpretation--Periodicals
# 		- Rowling, J. K.--Criticism and interpretation
# 		- Potter, Harry, (fiktiv gestalt)
# 		- Rowling, J. K.--Periodicals
# 		- Rowling, J. K, 1965-
# 		- Rowling, J. K.--Characters--Women--Periodicals
# 823.914 :
# 	- organisation:
# 		- Pottermore.com (Firm)
# 	- general term:
# 		- Girls in literature
# 		- Heroes in literature
# 		- Collectibles
# 		- Riddles in literature
# 		- LITERARY CRITICISM / Children's Literature
# 		- Transfiguration (Spiritualism)--Juvenile fiction
# 		- Multicultural education--California--Case studies
# 		- Interdisciplinary studies
# 		- Potter, Harry (Fictitious character)--Juvenile fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)
# 		- Popular literature--Study and teaching--Case studies
# 		- Wizards--Juvenile literature
# 		- Italian language materials
# 		- Literature and history
# 		- Magic--Juvenile literature
# 		- Religion and literature
# 		- EDUCATION / Teaching Methods & Materials / General
# 		- Wizards--Fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction
# 		- Magic--Psychological aspects
# 		- Fantasy literature, English--History and criticism
# 		- Children--Books and reading--English-speaking countries
# 		- Magic in literature--Juvenile literature
# 		- Wizards in literature--Juvenile literature
# 		- Identity (Philosophical concept) in literature
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Computer games
# 		- Fantasy fiction, English--History and criticism--Handbooks, manuals, etc
# 		- Literary recreations--Juvenile literature
# 		- Young adults--Books and reading
# 		- Children's stories--Psychological aspects
# 		- Symbolism in literature
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile literature
# 		- Racism in literature
# 		- Fantasy fiction, English--20th century--History and criticism
# 		- Magic wands--Specimens
# 		- Children's literature, English--History and criticism
# 		- Wizards--Miscellanea
# 		- Magic--Miscellanea
# 		- POLITICAL SCIENCE / History & Theory
# 		- Children's stories--History and criticism
# 		- Women novelists, English--20th century--Biography--Juvenile literature
# 		- Politics in literature
# 		- Mythology, Greek, in literature
# 		- Literature publishing--Great Britain--History--20th century
# 		- Harry Potter films--Collectibles
# 		- Mythology in literature
# 		- Novelists, English--20th century--Biography--Juvenile literature
# 		- EDUCATION / Multicultural Education
# 		- Fans (Persons)
# 		- Wizards--Juvenile fiction
# 		- POLITICAL SCIENCE / Political Ideologies / General
# 		- Creative teaching--Case studies
# 		- Fantasy fiction, English
# 		- Children's Literature
# 		- Toy and movable books
# 		- Leadership in literature
# 		- Wizards--Pictorial works--Juvenile fiction
# 		- Novelists, English--20th century--Biography
# 		- Alchemy--Juvenile fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction
# 		- Magic--Fiction
# 		- Children's stories, English--History and criticism
# 		- Literary Criticism & Collections
# 		- Classical literature--Influence
# 		- Cultural studies
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Miscellanea
# 		- Children's stories, English
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Fiction
# 		- Fantasy fiction, English--History and criticism
# 		- Children's stories, English--20th century--History and criticism
# 		- Law in literature
# 		- Potter, Harry (Fictitious character)--Miscellanea
# 		- Children's literature studies: general
# 		- Fantasy fiction, English--21st century--History and criticism
# 		- Literary studies: fiction, novelists & prose writers
# 		- Children's stories, English--21st century--History and criticism
# 		- Young adult fiction, English--Study and teaching
# 		- Potter, Harry (Fictional character)--Handbooks, manuals, etc
# 		- Literature and society
# 		- Generation Y--Political activity
# 		- EDUCATION / Philosophy & Social Aspects
# 		- Animals, Mythical--Juvenile literature
# 		- Children--Books and reading
# 		- Women in literature
# 		- JUVENILE NONFICTION / Literary Criticism & Collections
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Pictorial works--Juvenile literature
# 		- Fantasy fiction, English--Appreciation
# 		- Mythology, Roman, in literature
# 		- Courage in literature
# 		- Animals, Mythical--Pictorial works--Juvenile literature
# 		- Mythology, Indic
# 		- Political science
# 		- LITERARY CRITICISM--European--English, Irish, Scottish, Welsh
# 		- Miniature books--Specimens
# 		- Childhood in literature
# 		- Magic in literature
# 		- Wizards--Pictorial works--Juvenile literature
# 		- LITERARY COLLECTIONS / English, Irish, Scottish, Welsh
# 		- Education and state--United States
# 		- Fantasy fiction--Handbooks, manuals, etc
# 		- Magic--Juvenile fiction
# 		- Children's stories, English--Appreciation
# 		- Children's stories, English--History and criticism--Handbooks, manuals, etc
# 		- Creative teaching
# 		- Identity (Psychology) in literature
# 		- Masculinity in literature
# 		- Wizards in literature
# 		- Critical pedagogy--United States
# 		- Wizards in literature--Handbooks, manuals, etc
# 		- Fantasy stories, English
# 		- Magic in literature--Handbooks, manuals, etc
# 		- Literary landmarks--Great Britain
# 		- HISTORY / General
# 		- Adolescence in literature
# 		- Women novelists, English--20th century--Biography
# 		- Philosophy in literature
# 		- Mythology--Juvenile literature
# 		- Potter, Harry (Fictitious character)--Pictorial works--Juvenile fiction
# 		- Schools--Fiction
# 		- Toy and movable books--Specimens
# 		- Christianity and literature
# 		- POLITICAL SCIENCE / General
# 		- Fantasy fiction, English--Miscellanea--Juvenile literature
# 	- geographical term:
# 		- Great Britain--Description and travel
# 		- England--Fiction
# 	- person:
# 		- Rowling, J. K.--Criticism and interpretation--Computer network resources
# 		- Potter, Harry, (Fictitious character)--Pictorial works--Juvenile literature
# 		- Rowling, J. K.--Study and teaching
# 		- Rowling, J. K.--Juvenile literature
# 		- Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature
# 		- Rowling, J. K.--Film and video adaptations--Miscellanea--Juvenile literature
# 		- Rowling, J. K.--Characters--Miscellanea--Juvenile literature
# 		- Peter Pan, (Fictitious character)
# 		- Rowling, J. K.--Influence
# 		- Rowling, J. K.--Settings--Dictionaries, Juvenile
# 		- Rowling, J. K.--Characters--Harry Potter--Juvenile literature
# 		- Rowling, J. K.--Themes, motives
# 		- Rowling, J. K.--Stories, plots, etc
# 		- Rowling, J. K.--Settings
# 		- Potter, Harry, (Fictitious character)--Juvenile fiction
# 		- Rowling, J. K.--Criticism and interpretation
# 		- Rowling, J. K.--Stories, plots, etc--Juvenile literature
# 		- Potter, Harry, (Fictitious character)--Computer games
# 		- Potter, Harry, (Fictitious character)--Handbooks, manuals, etc
# 		- Rowling, J. K.--Characters--Dictionaries, Juvenile
# 		- Potter, Harry, (Fictitious character)--Collectibles
# 		- Rowling, J. K.--Appreciation
# 		- Rowling, J. K.--Illustrations--Juvenile literature
# 		- Rowling, J. K.--Characters
# 		- Anelli, Melissa
# 		- Rowling, J. K.--Characters--Girls
# 		- Potter, Harry, (Fictitious character)--Dictionaries, Juvenile
# 		- Rowling, J. K.--Characters--Handbooks, manuals, etc
# 		- Rowling, J. K.--Ethics
# 		- Rowling, J. K.--Characters--Harry Potter
# 		- Rowling, J. K.--Miscellanea
# 		- Rowling, J. K.--Political and social views
# 		- Rowling, J. K.--Characters--Harry Potter--Handbooks, manuals, etc
# 		- Potter, Harry, (Fictitious character)--Juvenile literature
# 		- Potter, Harry, (Fictitious character)
# 		- Rowling, J. K
# 		- Rowling, J. K.--Philosophy
# 		- Potter, Harry, (Fictitious character)--Computer network resources
# 		- Rowling, J. K.--Study and teaching--Case studies
# 		- Potter, Harry, (Fictitious character)--Fiction
# 		- Rowling, J. K.--Religion
# 		- Rowling, J. K.--Characters--Juvenile literature
# 		- Rowling, J. K.--Collectibles
# 		- Rowling, J. K.--Characters--Women
# 	- title:
# 		- Leaky cauldron
# 		- Bible--In literature
# 823.92 :
# 	- general term:
# 		- Magic in literature
# 		- Children's stories, English
# 		- Heroes in literature
# 		- Fantasy fiction, English--History and criticism
# 		- Christian art and symbolism in literature
# 		- Potter, Harry (Fictitious character)--Miscellanea
# 		- Archetype (Psychology) in literature
# 		- Masculinity in literature
# 		- Harry Potter films--Juvenile literature
# 		- Women authors, English--21st century--Juvenile literature
# 		- Women novelists, English--20th century--Biography--Juvenile literature
# 		- Mythology in literature
# 		- Novelists, English--20th century--Biography--Juvenile literature
# 		- Potter, Harry (Fictitious character)--Juvenile fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)
# 		- Harry Potter films
# 		- Wizards in literature
# 		- Wizards--Juvenile fiction
# 		- Allusions in literature
# 		- Religion and literature
# 		- Wizards--Fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary place)--Juvenile fiction
# 		- Fantasy fiction, English
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Fiction
# 		- Harry Potter films--Miscellanea
# 		- Children--Books and reading--English-speaking countries
# 		- Philosophy in literature
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction
# 		- Children's stories, English--History and criticism
# 	- person:
# 		- Rowling, J. K.--Characters--Collectibles
# 		- Rowling, J. K.--Themes, motives
# 		- Rowling, J. K.--Characters--Harry Potter
# 		- Potter, Harry, (Fictitious character)--Congresses
# 		- Potter, Harry, (Fictitious character)--Collectibles
# 		- Rowling, J. K.--Characters--Harry Potter--Congresses
# 		- Potter, Harry, (Fictitious character)--Juvenile literature
# 		- Potter, Harry, (Fictitious character)
# 		- Rowling, J. K.--Characters
# 		- Rowling, J. K.--Criticism and interpretation--Congresses
# 		- Rowling, J. K.--Juvenile literature
# 		- Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature
# 		- Rowling, J. K
# 		- Rowling, J. K.--Characters--Miscellanea--Juvenile literature
# 		- Potter, Harry, (Fictitious character)--Fiction
# 		- Rowling, J. K.--Characters--Miscellanea
# 		- Potter, Harry, (Fictitious character)--Juvenile fiction
# 		- Rowling, J. K.--Criticism and interpretation
# 828.91402 :
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Miscellanea--Juvenile literature
# 828.9207 :
# 	- general term:
# 		- Children's stories--Forecasting--Juvenile literature
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Juvenile literature
# 895.43 :
# 	- general term:
# 		- Wizards
# 		- Magic--Juvenile fiction
# 		- Schools
# 		- Schools--Juvenile fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)--Juvenile fiction
# 		- Hogwarts School of Witchcraft and Wizardry (Imaginary organization)
# 		- Magic
# 		- Wizards--Juvenile fiction
# 	- geographical term:
# 		- England--Juvenile fiction
# 		- England
# 	- person:
# 		- Potter, Harry, (Fictitious character)--Juvenile fiction
# 		- Potter, Harry, (Fictitious character)

# %% [markdown]
# # Reproduce the British Library organization
# In order to construct our three sections (notated music, texts and online resources)
#  * we create a new empty list, *listTypes*, that will include tuples in the form *('Content type','BL record ID')*
#  * we iterate over the rows of the csv file to extract data from 'Content type' and 'BL record ID' fields
#  * we store such values as items of tuples in *listTypes*
#
# To group BL IDs by type of content we first define a new **defaultdict** called *types* whose values are defined as lists by default. Then we iterate over each pair of items in the tuples (*k*, *v*) included in *listTypes* and we store them as unique keys *k* and a list as value *v*.

# %%
import csv 
from collections import defaultdict

listTypes = []

with open('topics.csv', 'r', errors='ignore') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # 2. type classification: create a list of tuples including the type and the BNB number
        listTypes.append( (row['Content type'], row['BL record ID'] ) )

# clean the list of types and BL IDs
types = defaultdict(list)
for k, v in listTypes:
    types[k].append(v)

# %% [markdown]
# We print our results in a prettier way by directly iterating over the new defaultdict.

# %%
# print the list of types and BL IDs
for key, blnumbers in types.items():
    print(key+': ')
    for blnumber in set(blnumbers):
        if blnumber is not '':
            print('- ', blnumber)
