# %% [markdown]
# ## Look at data
# Look at the .csv file, study its structure and where to find the information we need.
#
# Outline the issues you might have (e.g. which fieldnames I need to provide the citation? Do the values are clean?)
#
# ## Collect resources required
# In the first line of the .py script we add a comment to tell the interpreter which encoding standard has to use when dealing with our data.

# %%
# coding: utf-8

# %% [markdown]
# Then we import the modules we'll need to accomplish our tasks, such as *csv* for reading and manipulating a .csv file.

# %%
import csv

# %% [markdown]
# # Is there any duplicate in the list? Print the list of duplicates in the form `ISBN: number`

# %% [markdown]
# We define a function that looks into values of a fieldname in a .csv file, and returns a list of values that appear more than once. First we name the function, e.g. **findDuplicates**, that accepts as arguments two strings: the path of the csv file, and the fieldname for the lookup function.

# %%
def findDuplicates(inputFile, fieldName):
    ''' given a csv file in input and a field name for disambiguating records,
    returns a list of duplicates'''

# %% [markdown]
# We prepare an empty list, named *listDisambiguate*, to store all the values that appear several times in the field 'ISBN' - which is a standard for identifying unique bibliographic references. We also create a list called *duplicates*, wherein we'll store only the repeated ones. We use the compact syntax to declare both of them in the same line.

# %%
listDisambiguate , duplicates = [] , []

# %% [markdown]
# We open the .csv file - in the same way we learnt in the last lesson - but we do not specify the name of the file. We use a variable instead, *inputFile*. This will ensure that the function can be reused for the same purposes with other files (in future).
#
# We iterate over the rows of the csv (that have been converted in dictionaries through the function **dictReader**) and we fill the empty list named *listDisambiguate* with all the values of the field 'ISBN'. Likewise the name of the file, here we do not explicit the name of the field, that can vary according to the input file.

# %%
with open(inputFile, 'r', errors='ignore') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader: 
        listDisambiguate.append(row[fieldName])

# %% [markdown]
# Now that we have the list of all the ISBN numbers, we fill the list *duplicates* whith only the strings that appear more than once. We use the class **Counter**, that we have already seen: this returns a dictionary  to count items in the

# %%
from collections import Counter
for item, count in Counter(listDisambiguate).items():
    if count > 1:
        duplicates.append(item)
duplicates
# Out:
# ['',
#  '9781783052578',
#  '9788374323079',
#  '1861891717',
#  '1900924927',
#  '0335150659',
#  '2207256138 ; 9782207256138',
#  '0670838454',
#  '8445135147 ; 9788445135143',
#  '1910705187 ; 9781910705186',
#  '9781632151803',
#  '1550545981',
#  '9780316270397',
#  '0887846068',
#  '0956642098 ; 9780956642097',
#  '0473289067 ; 9780473289065',
#  '9780957260009',
#  '1843534738 ; 9781843532644',
#  '',
#  '9781783052578',
#  '9788374323079',
#  '1861891717',
#  '1900924927',
#  '0335150659',
#  '2207256138 ; 9782207256138',
#  '0670838454',
#  '8445135147 ; 9788445135143',
#  '1910705187 ; 9781910705186',
#  '9781632151803',
#  '1550545981',
#  '9780316270397',
#  '0887846068',
#  '0956642098 ; 9780956642097',
#  '0473289067 ; 9780473289065',
#  '9780957260009',
#  '1843534738 ; 9781843532644',
#  '',
#  '9781783052578',
#  '9788374323079',
#  '1861891717',
#  '1900924927',
#  '0335150659',
#  '2207256138 ; 9782207256138',
#  '0670838454',
#  '8445135147 ; 9788445135143',
#  '1910705187 ; 9781910705186',
#  '9781632151803',
#  '1550545981',
#  '9780316270397',
#  '0887846068',
#  '0956642098 ; 9780956642097',
#  '0473289067 ; 9780473289065',
#  '9780957260009',
#  '1843534738 ; 9781843532644',
#  '',
#  '9781783052578',
#  '9788374323079',
#  '1861891717',
#  '1900924927',
#  '0335150659',
#  '2207256138 ; 9782207256138',
#  '0670838454',
#  '8445135147 ; 9788445135143',
#  '1910705187 ; 9781910705186',
#  '9781632151803',
#  '1550545981',
#  '9780316270397',
#  '0887846068',
#  '0956642098 ; 9780956642097',
#  '0473289067 ; 9780473289065',
#  '9780957260009',
#  '1843534738 ; 9781843532644',
#  '',
#  '9781783052578',
#  '9788374323079',
#  '1861891717',
#  '1900924927',
#  '0335150659',
#  '2207256138 ; 9782207256138',
#  '0670838454',
#  '8445135147 ; 9788445135143',
#  '1910705187 ; 9781910705186',
#  '9781632151803',
#  '1550545981',
#  '9780316270397',
#  '0887846068',
#  '0956642098 ; 9780956642097',
#  '0473289067 ; 9780473289065',
#  '9780957260009',
#  '1843534738 ; 9781843532644']

# %% [markdown]
# To clean the list and obtain a list of unique duplicates we use **set()**

# %%
list(set(duplicates))
# Out:
# ['',
#  '0670838454',
#  '0335150659',
#  '1861891717',
#  '1910705187 ; 9781910705186',
#  '0473289067 ; 9780473289065',
#  '9781783052578',
#  '1550545981',
#  '0956642098 ; 9780956642097',
#  '8445135147 ; 9788445135143',
#  '9780957260009',
#  '9788374323079',
#  '9780316270397',
#  '2207256138 ; 9782207256138',
#  '1843534738 ; 9781843532644',
#  '9781632151803',
#  '1900924927',
#  '0887846068']

# %% [markdown]
# We can use list comprehension to obtain the same result, but with only one line of code.

# %%
from collections import Counter
duplicates = [item for item, count in Counter(listDisambiguate).items() if count > 1]
duplicates
# Out:
# ['',
#  '9781783052578',
#  '9788374323079',
#  '1861891717',
#  '1900924927',
#  '0335150659',
#  '2207256138 ; 9782207256138',
#  '0670838454',
#  '8445135147 ; 9788445135143',
#  '1910705187 ; 9781910705186',
#  '9781632151803',
#  '1550545981',
#  '9780316270397',
#  '0887846068',
#  '0956642098 ; 9780956642097',
#  '0473289067 ; 9780473289065',
#  '9780957260009',
#  '1843534738 ; 9781843532644']

# %% [markdown]
# Therefore, our final function will looks like:

# %%
# coding: utf-8
import csv , re
from collections import Counter

def findDuplicates(inputFile, fieldName):
    ''' given a csv file in input and a field name for disambiguating records,
    returns a list of duplicates'''
    listDisambiguate = []

    with open(inputFile, 'r', errors='ignore') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader: # iterates over the lines in the .csv file / i.e., key, value of the dictionary
            listDisambiguate.append(row[fieldName]) # look into a column and create a list
        duplicates = [item for item, count in Counter(listDisambiguate).items() if count > 1]

        print('\nDuplicates in list:')
        for dupl in duplicates:
            print((fieldName+':'+dupl))

# %% [markdown]
# That we can call with our specific parameters.

# %%
findDuplicates('titles.csv', 'ISBN')
# Out:
# Duplicates in list:
# ISBN:
# ISBN:9781783052578
# ISBN:9788374323079
# ISBN:1861891717
# ISBN:1900924927
# ISBN:0335150659
# ISBN:2207256138 ; 9782207256138
# ISBN:0670838454
# ISBN:8445135147 ; 9788445135143
# ISBN:1910705187 ; 9781910705186
# ISBN:9781632151803
# ISBN:1550545981
# ISBN:9780316270397
# ISBN:0887846068
# ISBN:0956642098 ; 9780956642097
# ISBN:0473289067 ; 9780473289065
# ISBN:9780957260009
# ISBN:1843534738 ; 9781843532644

# %% [markdown]
# # Can you delete duplicates from the dictionary?
# We define a function that cleans a *list of dictionaries* (such as the one created by **dictReader**) by deleting all the dictionaries that are repeated. This means we delete all the records that are repeated in bibliography.
#
# As usual, we provide the function of a name (**cleanListOfDict**) and optional arguments. In this case we ask for a list of dictionaries and we return a new cleaned list of dictionaries.

# %%
def cleanListOfDict(oldList):
    ''' given a list of dictionaries with duplicate items
    returns a new cleaned list of dictionaries'''
    newList = []

# %% [markdown]
# We have prepared an empty list, *newList*, to store only the unique dictionaries.
#
# Then we iterate over the length of the list. We use the built-in function **range()** to create a sequence of numbers, from 0 to the maximum number of items included in the list to be cleaned, i.e., *len(oldList)*. This creates an index of positions for all the dictionaries included in the original list, that we'll use to see whether an item (dictionary) is repeated in the next ones.
#
# The **if clause** asks for any dictionary in the current position \[i\] that is not repeated in the following siblings. *i* is a number included between 0 and len(oldList) that increases iteratively (*i+1*). We use the membership operator **not in** to compare any dictionary to all the following ones (then the notation *i+1:*, that means: from i, with a step of 1, till the end of the sequence, expressed by :).
#
# If the condition is satisfied, the dictionary is copied in the new list.

# %%
    for i in range(0, len(oldList)):
        if oldList[i] not in oldList[i+1:]: 
            newList.append(oldList[i]) 
    return newList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4e2103b7abcf> in <module>()
# ----> 1 for i in range(0, len(oldList)):
#       2     if oldList[i] not in oldList[i+1:]:
#       3         newList.append(oldList[i])
#       4 return newList
#
# NameError: name 'oldList' is not defined

# %% [markdown]
# Or better, we can further simplify the code by using list comprehension:

# %%
newList = [oldList[i] for i in range(0, len(oldList)) if oldList[i] not in oldList[i+1:]]

# %% [markdown]
# Our final function looks like:

# %%
def cleanListOfDict(oldList):
    ''' given a list of dictionaries with duplicate items
    returns a new cleaned list of dictionaries'''
    newList = [oldList[i] for i in range(0, len(oldList)) if oldList[i] not in oldList[i+1:]]
    return newList

# %% [markdown]
# For example, we can call the function with a simple list of dictionaries as parameter:

# %%
anotherList = [{'a': 100}, {'b': 100}, {'a': 100}]
cleanListOfDict(anotherList)
# Out:
# [{'b': 100}, {'a': 100}]

# %% [markdown]
# It returns only the unique dictionaries as we wanted. So we are sure our function works.
#
# Now we try it with the list of dictionaries that we obtain from opening the .csv file with *dictReader*.

# %%
with open('titles.csv', 'r', errors='ignore') as csvfile:
    reader = [row for row in csv.DictReader(csvfile)]
    clean = cleanListOfDict(reader)
#check how many rows have been deleted 
print('new:',len(clean),' old:',len(reader) )
# Out:
# new: 323  old: 323

# %% [markdown]
# Oooops, apparently we have not deleted any row! But the function works.. This means that even if there are duplicates in ISBN numbers, other data in the same row is different, e.g. two different titles are recorded, or different topics.
# We should decide which record is the most reliable among the duplicates and exclude the others.. But for moment this is enough! Let's move to another task.

# %% [markdown]
# # Print references in Chicago Style
# A bibliographic citation in Chicago Style looks like:
#
# `LastName1, FirstName1, FirstName2 LastName2, and FirstNameN LastNameN. Title. City: Publisher, date.`
#
# The information we need in order to build the citation is split in several fields: 'All names', 'Title', 'Place of publication', 'Publisher', ande 'Date of publication'.
#
# Looking at the column of authors ('All names') we immediately notice that last names and first name are not in the correct order, and that strings have to be cleaned (removing parentheses, and roles). Since the task of cleaning such a string is quite expensive, we create a bespoke function for that purpose, and we call it inside a more general function that only builds the citation.
#
# We summary the operations we need to perform on such string before starting (the sequence is relevant!). We observe two situations: single author and multiple authors. Few operations must be performed case by case. Some others can be performed despite the variable number of authors (i.e., in both case at once).
#
#  * **multiple authors** delete all the organisations from the list
#  * **multiple authors** delete roles
#  * **multiple authors** swap last name and first name for all the authors but the first one, and remove the comma
#  * **multiple authors** add 'and' before the last author
#  * **single author** delete roles
#  * **both multiple authors and single author** remove parenthesis and dates
#  * **both multiple authors and single author** delete the semicolon and place a comma instead
#
# As usual we start working with lists, therefore we create empty lists for storing our data (the list of authors and the final list of authors' names in the correct order).

# %%
    authors , cleanAuthors = [] , [] # create a list with authors, prepare the list to store the cleaned list of authors

    with open('titles.csv', 'r', errors='ignore') as csvfile:
        reader = csv.DictReader(csvfile)
        authors = [row['All names'] for row in reader] # we used list comprehension to make it short
        print(authors)
# Out:
# ['Evans, Mike [person]', 'Jones, Steven [person]', 'Marcus, Greil [person]', 'Gibbon, Peter [person] ; Centret for udviklingsforskning (Denmark) [organisation]', 'Butler, Chris [person]', 'Mulholland, Garry [person]', 'Wright, Peter Poyntz [person]', 'Wells, Steven [person]', 'Jasper, Maura [person] ; Mancini, Hilken [person]', 'McGuirk, Niall [person]', 'Ercoli, Rikki [person]', 'Jocoy, Jim, 1952- [person] ; Moore, Thurston [person] ; Cervenka, Exene [person]', 'Walsh, Gavin, 1964- [person]', 'King, John, 1960- [person]', 'Cannon, Brian John Matthew [person]', 'Bayley, Roberta [person]', 'Bockris, Victor, 1949- [person]', 'Rocco, John (John M.) [person]', 'McIver, Joel [person]', 'Anscombe, Isabelle [person]', "O'Regan, Denis [person]", 'Belsito, Peter [person] ; Davis, Bob [person] ; Kester, Marion [person]', 'Leblanc, Lauraine, 1968- [person]', 'Alexandersson, Gunvor [person] ; Lundquist, Lena [person]', 'Teipel, Jürgen [person]', 'Ogram, patippu [person]', 'Kerr, Joe, 1958- [person] ; Gibson, Andrew, 1949- [person]', 'Caiafa, Janicł [person]', 'Stevenson, Nils [person] ; Stevenson, Ray [person]', "O'Hara, Craig [person]", "O'Hara, Craig [person]", 'Vague, Tom [person]', 'Fielding, Garry [person]', 'Home, Stewart, 1962- [person]', 'Zimmermann, Peter, writer [person]', 'May, Michael, 1956- [person]', 'Coon, Caroline [person]', '', 'King, John, 1960- [person]', 'Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]', 'Craine, Nick, 1971- [person] ; Turner, Michael, 1962- [person] ; MacDonald, Bruce [person]', 'Craine, Nick, 1971- [person] ; Turner, Michael, 1962- [person] ; MacDonald, Bruce [person]', 'Carr, Emily, 1871-1945 [person]', 'Carr, Emily, 1871-1945 [person]', 'Mulholland, Garry [person]', 'McNeil, Legs [person] ; McCain, Gillian [person]', 'Steel, Mark, 1960- [person]', 'Davis, Guy, 1966- [person] ; Reed, Gary, 1956- [person]', 'Dellar, Robert [person]', 'Sams, Gideon, 1962-1989 [person]', 'McLaren, Louise [person]', 'Aizlewood, John [person] ; Collins, Andrew, 1965- [person] ; Prince, Bill [person]', 'Aizlewood, John [person] ; Collins, Andrew, 1965- [person] ; Prince, Bill [person]', 'Helander, Brock [person]', 'Laing, Dave, 1947- [person]', 'McNeil, Legs [person] ; McCain, Gillian [person]', 'Sabin, Roger, 1961- [person]', 'Rimmer, Dave [person]', 'Savage, Jon [person]', 'Perry, Mark, vocalist [person] ; Rawlings, Terry, 1933- [person]', 'Roach, Martin, 1969- [person]', 'Joynson, Vernon [person]', 'Taylor, Steven, 1955- [person]', 'Hayward, Philip, editor [person]', '', '', 'Savage, Jon [person]', 'Savage, Jon [person]', 'Russell, Bill, 1949- [person]', "O'Connell, Terry [person]", 'Wright, Peter Poyntz [person]', 'Dickson, Ian, 1945- [person]', 'Grushkin, Paul D. [person]', 'Sex Pistols (Musical group) [organisation]', 'Heubner, Thomas, 1951- [person]', 'Carroll, Jessica, 1976- [person] ; Smith, Craig, 1955- [person]', 'Henri, Adrian, 1932- [person] ; Walker, Roger Wade [person]', 'Echenberg, Erica [person] ; P., Mark [person]', 'Coon, Caroline [person]', 'Marcus, Greil [person]', 'Chidolue, Dagmar, 1944- [person] ; Mathieu, François [person]', 'Gjedsted, Jens Jørn [person]', 'Kaz [person]', 'Holm, Benn Q., 1962- [person]', 'Fogwill, Rodolfo Enrique [person]', 'Bessy, Claude [person] ; Track 16 Gallery and Mainspace [organisation]', 'Grushkin, Paul D. [person]', '', 'Laing, Dave [person]', 'Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]', 'Henri, Adrian, 1932- [person] ; Walker, Roger Wade [person]', 'Coon, Caroline, 1945- [person]', 'Sams, Gideon, 1962-1989 [person]', 'Seiler, Burkhardt, 1953- [person]', 'Sams, Gideon, 1962-1989 [person]', 'Sams, Gideon, 1962-1989 [person]', 'Poulsen, Henrik Bech [person]', 'Poulsen, Henrik Bech [person]', 'Turcotte, Bryan Ray [person] ; Miller, Christopher T. [person]', '', '', '', 'Savage, Jon [person]', 'Levy, Patricia, 1951- [person]', 'Heylin, Clinton [person]', 'Rombes, Nicholas [person]', 'Milner, Frank [person] ; Walker Art Gallery [organisation] ; Lady Leve ...

# %% [markdown]
# Then we work only on the list of authors we created and we iterate over its items to clean every string representing a single author.
#
# The first scenario we deal with is whether we have only one author or several ones separated by ';'. In the latter case we split single authors belonging to a group and we clean them singularly. Since there are no other situations at this level (i.e., only ';' is used to separate authors) we use an **if else statement**.

# %%
for auth in authors: 
    if ';' in auth:
        # clean every author's name
    else:
        # clean only on author's name
# Out:
#   File "<ipython-input-72-b132c6a60bdd>", line 4
#     else:
#        ^
# IndentationError: expected an indented block

# %% [markdown]
# We start with the case of multiple authors, since is the most complex situation.
#
# First of all, we use **split(';')** to divide authors' names separated by ';' and we get a sequence of names.
#
# Secondly we remove from the sequence all the names that refer to organisations, since they can not be considered authors. We use the membership operator **in** to check whether a string contains the word 'organisation' and then we update the list of single names 'splitList' using list comprehension.
#
# Then we iterate over each author's name and we split this string by the separator ',' (so that we retrieve, first name, last name, and roles). If there are more than three items in such a list, it means that the third string and following ones are roles (e.g. 'author', 'writer', etc.) and we delete them. Then we update the list of names replacing the whole string: we join the first name and last name with ', ', as it was in the beginning. If there are only two items separated by comma, but the second string is 'artist' or 'author', we delete the second item and we update again the list of a signle author (that in this case corresponds to the first item in *splitList2*).
#
# Finally, we join the substrings we cleaned with ';' and we recreate the string representing a group of authors of a single publication (auth). Rebuilding the original string continuously is necessary because several operations we need to perform later require a precise sequence (e.g. if we delete ';' we can not recognize clearly boundaries of authors' names, therefore it needs to be the last object to be cleaned).

# %%
for auth in authors: 
    if ';' in auth: # multiple authors
        splitList = auth.split(';') # split a group of authors by semicolon
        splitList = [au for au in splitList if 'organisation' not in au] # remove organizations from the list of authors
        for au in splitList: # iterate over each author in a group
            splitList2 = au.split(',') # split parts of the name of a single author by comma
            if len(splitList2) >=3: # after removing organisations, if there are still more than one author
                del splitList2[2:] # delete the substring after the third comma if exists (e.g. author, writer)
                splitList = [auth.replace(au, ', '.join(aux.strip() for aux in splitList2))] 
            if (len(splitList2) == 2) and ('artist' in splitList2[1] or 'author' in splitList2[1]) : # delete artist when in second position
                del splitList2[1]
                splitList = splitList2
        auth = ';'.join(au for au in splitList if au != ' ')
        print(auth) # print all the multiple authors
# Out:
# Gibbon, Peter [person]
# Jasper, Maura [person] ; Mancini, Hilken [person]
# Jocoy, Jim, 1952- [person] ; Moore, Thurston [person] ; Cervenka, Exene [person]
# Belsito, Peter [person] ; Davis, Bob [person] ; Kester, Marion [person]
# Alexandersson, Gunvor [person] ; Lundquist, Lena [person]
# Kerr, Joe, 1958- [person] ; Gibson, Andrew, 1949- [person]
# Stevenson, Nils [person] ; Stevenson, Ray [person]
# Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]
# Craine, Nick, 1971- [person] ; Turner, Michael, 1962- [person] ; MacDonald, Bruce [person]
# Craine, Nick, 1971- [person] ; Turner, Michael, 1962- [person] ; MacDonald, Bruce [person]
# McNeil, Legs [person] ; McCain, Gillian [person]
# Davis, Guy, 1966- [person] ; Reed, Gary, 1956- [person]
# Aizlewood, John [person] ; Collins, Andrew, 1965- [person] ; Prince, Bill [person]
# Aizlewood, John [person] ; Collins, Andrew, 1965- [person] ; Prince, Bill [person]
# McNeil, Legs [person] ; McCain, Gillian [person]
# Perry, Mark, vocalist [person] ; Rawlings, Terry, 1933- [person]
# Carroll, Jessica, 1976- [person] ; Smith, Craig, 1955- [person]
# Henri, Adrian, 1932- [person] ; Walker, Roger Wade [person]
# Echenberg, Erica [person] ; P., Mark [person]
# Chidolue, Dagmar, 1944- [person] ; Mathieu, François [person]
# Bessy, Claude [person]
# Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]
# Henri, Adrian, 1932- [person] ; Walker, Roger Wade [person]
# Turcotte, Bryan Ray [person] ; Miller, Christopher T. [person]
# Milner, Frank [person]
# Gordon, Alastair Robert [person]
# Jones, Preston, 1966- [person] ; Graffin, Greg [person]
# Letts, Don [person] ; Nobakht, David [person]
# Triggs, Teal Ann [person]
# Reddington, Helen [person]
# Benevides, Alyce [person] ; Milles, Jaqueline [person]
# Sladen, Mark [person] ; Yedgar, Ariella [person]
# Wallace, Amy [person] ; Manitoba, Handsome Dick [person]
# Letts, Don [person] ; Nobakht, David [person]
# Smith, Bobby [person] ; Oshindele-Smith, Margaret, 1966- [person]
# Santos, Raye [person] ; McCaffrey, Richard [person] ; Fitzgerald, f-Stop [person] ; Klein, Howie [person]
# Kelley, Trevor [person] ; Simon, Leslie [person]
# Kramer, Fred, 1960- [person] ; Vos, Margot [person]
# Ostow, Micol [person] ; Ostow, David, 1979- [person]
# Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]
# Boulware, Jack [person] ; Tudor, Silke [person]
# Vee, Tesco [person] ; Stimson, Dave [person] ; Miller, Steve [person]
# Carlson, Zack [person] ; Connolly, Bryan [person]
# Tulien, Sean [person] ; Aburto, Jesus [person]
# Leigh, Mickey [person] ; McNeil, Legs [person]
# Williamson, Aaron [person] ; Wright, Adam [person] ; Collins, Tony [person]
# Williamson, Aaron [person] ; Wright, Adam [person] ; Collins, Tony [person]
# Watkins, Matt, editor [person] ; Inglefield, Mark, editor [person]
# McMurray, Jacob [person]
# Dale, Pete R. W. [person]
# Stewart, Francis Elizabeth [person]
# Bestley, Russell [person] ; Ogg, Alex [person]
# Kerr, Joe, 1958-, editor [person] ; Gibson, Andrew, 1949-, editor [person]
# Ebersole, Stewart Dean [person] ; Castaldi, Jared [person]
# Seven, John [person] ; Christy, Jana [person]
# Johnson, Mark [person]
# Markey, Dave, 1963- [person] ; Schwartz, Jordan [person]
# Harvey, Paul, author [person]
# Matthews, John, 1948- [person] ; Matthews, Caitkin [person] ; Kinghan, Wil [person]
# Singleton, David, 1961-, author [person] ; Singleton, Ben, artist, cartoonist [person] ; Sanderson, Punk [person]
# Savage, Jon, editor, interviewer [person] ; Baker, Stuart, editor, interviewer, writer [person] ; Reid, Jamie, 1947-, writer [person] ; Vaucher, Gee, writer [person]
# Savage, Jon, editor, interviewer [person] ; Baker, Stuart, editor, interviewer, writer [person] ; Reid, Jamie, 1947-, writer [person] ; Vaucher, Gee, writer [person]
# Savage, Jon, editor, interviewer [person] ; Baker, Stuart, editor, interviewer, writer [person] ; Reid, Jamie, 1947-, writer [person] ; Vaucher, Gee, writer [person]
# Cross, Daniel, Documentary filmmaker [person] ; Roach [person]
# Ashton-Smith, Alan, author [person]
# Raposo, Ana Bastos, author [person]
# Suterwalla, Shehnaz, author [person]
# Bonello Rutter Giappone, Krista, author [person]
# Bestley, Russell, author [person] ; Ogg, Alex, author [person]
# Sutu, artist, author [person]
# Sutu, artist, author [person]
# Ryde, Robin [person] ; Sofianos, Lisa [person] ; Waterhouse, Charlie [person]
# Sutu, artist, author [person]
# Bucayu, Mike, editor [person] ; Driesler, Steve, editor [person] ; Furnish, Timothy, editor [person]
# Himelstein, Abram Shalom, author [person] ; Schweser, Jamie, author [person]
# Davis, Guy, 1966-, author [person] ; Reed, Gary, 1956-, author [person]
# Green Scum, 1962-, author [person] ; Bux, Lucie, illustrator [person]
# Lazarov, Dale, artist [person] ; Mariotti, Mauro, artist [person] ; Janecki, Janos, artist [person]
# Silva, Augusto Santos, 1956- [person] ; Guerra, Paula [person]
# Mattioli, Heath, author [person] ; Spacone, David, author [person]
# Xiao, Jian, author [person]
# Torcinovich, Matteo, author [person] ; Girardi, Sebastiano, author [person]
# Lohman, Kirsty, author [person]
# Doe, John, 1954-, author, editor [person] ; DeSavia, Tom, author, editor [person]
# Bunn, Cullen, author [person] ; Cm Punk, 1978-, author [person] ; Hepburn, Scott, artist [person]
# Narita, Ryōgo, 1980-, author [person] ; Enami, Katsumi, illustrator [person]
# Narita, Ryōgo, 1980-, author [person] ; Enami, Katsumi, illustrator [person]

# %% [markdown]
# Our strings are now partially cleaned. The next step is to swap the last name and the first name of all the authors but the first one.
#
# We split again the string (auth) by ';' and we use another **if statement** to check whether there are only two items (which means that there is nothing after ';') or there are more than two authors (and therefore we need to swap even and odd items).
#
# We deal with the first item in the list (first author): here we just strip spaces using the function **strip**, that removes both left and right redundant whitespaces.
#
# We then move to the other items (we use the notation *\[1:\]* to take all the items from the second to the end of the sequence), and we split all of them by ',' to retrieve first names and last names. By using variable assignment in one line, we swap the first item with the second one. Once this is done, we rebuild the full name of the author (now called *i* to avoid confusion): we replace for each author group (auth) the old string by joining first name and last name (au) with a white space. Then we rebuild the group of authors (auth) by joining each authors' name with a comma.
#
# Lastly, we add 'and' before the last author in the group (auth). We split the string (auth) again and we assign a new value to the last item of the list (see the notation *\[-1\]*). As usual we rebuild our string representing a group of authors with **join**.

# %%
# repeat the code for the interpreter of jupyter
for auth in authors: 
    if ';' in auth:      
        splitList = auth.split(';') # split a group of authors by semicolon
        splitList = [au for au in splitList if 'organisation' not in au] # remove organizations from the list of authors
        for au in splitList: # iterate over each author in a group
            splitList2 = au.split(',') # split parts of the name of a single author by comma
            if len(splitList2) >=3: # if there are more than three items, the last ones are roles
                del splitList2[2:] # delete the substring after the third comma if exists (e.g. author, writer)
                splitList = [auth.replace(au, ', '.join(aux.strip() for aux in splitList2))] 
            if (len(splitList2) == 2) and ('artist' in splitList2[1] or 'author' in splitList2[1]) : # delete artist when in second position
                del splitList2[1]
                splitList = splitList2 # delete role when there is only the name of art
        auth = ';'.join(au for au in splitList if au != ' ') # rebuild the string
        
# new code
        splitList = auth.split(';')  # split again the string to swap names
        if len(splitList) >= 2: # when there is more than one author
            for i in splitList[0]: # deal with the first author 
                i = i.strip() # remove whitespace in the first author's name
            for i in splitList[1:]: # deal with all the other authors' names 
                if ',' in i: 
                    splitList2 = i.split(',') # split each author's name by comma
                    splitList2[0], splitList2[1] = splitList2[1], splitList2[0] # swap last name and first name
                    splitList = [auth.replace(i, ' '.join(i for i in splitList2))] # rebuild the list of names
                    auth = ', '.join(au for au in splitList if au != ' ') # rebuild the list of authors
            
            splitList = auth.split(';') # split again the (updated) list of multiple authors
            splitList[-1] = str(' and '+splitList[-1]) # add "and" before the last author, after swapping last/first name
            auth = ';'.join(au for au in splitList if au != ' ') # update the list again
        print(auth)
# Out:
# Gibbon, Peter [person]
# Jasper, Maura [person] ; and  Hilken [person]  Mancini
# Jocoy, Jim; Thurston [person]   Moore; and  Exene [person]  Cervenka
# Belsito, Peter [person] ; Bob [person]   Davis; and  Marion [person]  Kester
# Alexandersson, Gunvor [person] ; and  Lena [person]  Lundquist
# Kerr, Joe, 1958- [person] ; and  Andrew Gibson
# Stevenson, Nils [person] ; and  Ray [person]  Stevenson
# Savage, Jon, editor, interviewer [person] ; Stuart  Baker  editor  interviewer  writer [person] ; Jamie  Reid  1947-  writer [person] ; and  Gee Vaucher
# Savage, Jon, editor, interviewer [person] ; Stuart  Baker  editor  interviewer  writer [person] ; Jamie  Reid  1947-  writer [person] ; and  Gee Vaucher
# Savage, Jon, editor, interviewer [person] ; Stuart  Baker  editor  interviewer  writer [person] ; Jamie  Reid  1947-  writer [person] ; and  Gee Vaucher
# Cross, Daniel; and  Roach [person]
# Ashton-Smith, Alan; and  Birkbeck College [organisation]
# Raposo, Ana Bastos; and  University of the Arts London [organisation]
# Suterwalla, Shehnaz; and  Royal College of Art (Great Britain) [organisation]
# Bonello Rutter Giappone, Krista; and  University of Kent [organisation]
# Bestley, Russell, author [person] ; and  Alex Ogg
# Sutu
# Sutu
# Ryde, Robin [person] ; Lisa [person]   Sofianos; and  Charlie [person]  Waterhouse
# Sutu
# Bucayu, Mike, editor [person] ; Steve  Driesler  editor [person] ; and  Timothy Furnish
# Himelstein, Abram Shalom, author [person] ; and  Jamie Schweser
# Davis, Guy, 1966-, author [person] ; and  Gary Reed
# Green Scum, 1962-, author [person] ; and  Lucie Bux
# Lazarov, Dale, artist [person] ; Mauro  Mariotti  artist [person] ; and  Janos Janecki
# Silva, Augusto Santos; and  Paula [person]  Guerra
# Mattioli, Heath, author [person] ; and  David Spacone
# Xiao, Jian; and  Loughborough University [organisation]
# Torcinovich, Matteo, author [person] ; and  Sebastiano Girardi
# Lohman, Kirsty; and  University of Warwick [organisation]
# Doe, John, 1954-, author, editor [person] ; and  Tom DeSavia
# Bunn, Cullen, author [person] ; 1978-  Cm Punk  author [person] ; and  Scott Hepburn
# Narita, Ryōgo, 1980-, author [person] ; and  Katsumi Enami
# Narita, Ryōgo, 1980-, author [person] ; and  Katsumi Enami

# %% [markdown]
# We did almost everything for what concerns groups of authors (few more stuff will be done in the end, for both groups of authors and single authors, e.g. removing parenthesis and dates). We now deal with single authors, by using the **else clause** that we left empty.
#
# We split our name by comma and we delete roles (that are all the items of the list 'splitList' after the second comma, i.e., *\[2:\]*). As for groups, we also take into account artists' names: when there are only two items separated by comma and the second one include the string 'artist' or 'author' we delete this item from the list. As usual, we rebuild the full string of the author's name (auth) joining the items with a comma.
#
# Finally, we need to take into account another exception we might have forgot. There might be empty groups of authors (i.e. a blank string). We substitute empty groups of authors with the string '-'.

# %%
for auth in authors: 
    if ';' in auth:
        pass # just for the sake of brevity, we skip the code here we have already seen
    else:
        splitList = auth.split(',') # split parts of the name of a single author by comma
        if len(splitList) >=3:
            del splitList[2:]
            splitList = [auth.replace(auth, ', '.join(aux.strip() for aux in splitList))]
        if (len(splitList) == 2) and ('artist' in splitList[1] or 'author' in splitList[1]) : # delete artist when in second position
            del splitList[1]
        auth = ','.join(au for au in splitList)
    if len(auth) == 0: # substitutes empty authors with -
        auth = '-'
    print(auth)
# Out:
# Evans, Mike [person]
# Jones, Steven [person]
# Marcus, Greil [person]
# Gibbon, Peter [person] ; Centret for udviklingsforskning (Denmark) [organisation]
# Butler, Chris [person]
# Mulholland, Garry [person]
# Wright, Peter Poyntz [person]
# Wells, Steven [person]
# Jasper, Maura [person] ; Mancini, Hilken [person]
# McGuirk, Niall [person]
# Ercoli, Rikki [person]
# Jocoy, Jim, 1952- [person] ; Moore, Thurston [person] ; Cervenka, Exene [person]
# Walsh, Gavin
# King, John
# Cannon, Brian John Matthew [person]
# Bayley, Roberta [person]
# Bockris, Victor
# Rocco, John (John M.) [person]
# McIver, Joel [person]
# Anscombe, Isabelle [person]
# O'Regan, Denis [person]
# Belsito, Peter [person] ; Davis, Bob [person] ; Kester, Marion [person]
# Leblanc, Lauraine
# Alexandersson, Gunvor [person] ; Lundquist, Lena [person]
# Teipel, Jürgen [person]
# Ogram, patippu [person]
# Kerr, Joe, 1958- [person] ; Gibson, Andrew, 1949- [person]
# Caiafa, Janicł [person]
# Stevenson, Nils [person] ; Stevenson, Ray [person]
# O'Hara, Craig [person]
# O'Hara, Craig [person]
# Vague, Tom [person]
# Fielding, Garry [person]
# Home, Stewart
# Zimmermann, Peter
# May, Michael
# Coon, Caroline [person]
# -
# King, John
# Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]
# Craine, Nick, 1971- [person] ; Turner, Michael, 1962- [person] ; MacDonald, Bruce [person]
# Craine, Nick, 1971- [person] ; Turner, Michael, 1962- [person] ; MacDonald, Bruce [person]
# Carr, Emily
# Carr, Emily
# Mulholland, Garry [person]
# McNeil, Legs [person] ; McCain, Gillian [person]
# Steel, Mark
# Davis, Guy, 1966- [person] ; Reed, Gary, 1956- [person]
# Dellar, Robert [person]
# Sams, Gideon
# McLaren, Louise [person]
# Aizlewood, John [person] ; Collins, Andrew, 1965- [person] ; Prince, Bill [person]
# Aizlewood, John [person] ; Collins, Andrew, 1965- [person] ; Prince, Bill [person]
# Helander, Brock [person]
# Laing, Dave
# McNeil, Legs [person] ; McCain, Gillian [person]
# Sabin, Roger
# Rimmer, Dave [person]
# Savage, Jon [person]
# Perry, Mark, vocalist [person] ; Rawlings, Terry, 1933- [person]
# Roach, Martin
# Joynson, Vernon [person]
# Taylor, Steven
# Hayward, Philip
# -
# -
# Savage, Jon [person]
# Savage, Jon [person]
# Russell, Bill
# O'Connell, Terry [person]
# Wright, Peter Poyntz [person]
# Dickson, Ian
# Grushkin, Paul D. [person]
# Sex Pistols (Musical group) [organisation]
# Heubner, Thomas
# Carroll, Jessica, 1976- [person] ; Smith, Craig, 1955- [person]
# Henri, Adrian, 1932- [person] ; Walker, Roger Wade [person]
# Echenberg, Erica [person] ; P., Mark [person]
# Coon, Caroline [person]
# Marcus, Greil [person]
# Chidolue, Dagmar, 1944- [person] ; Mathieu, François [person]
# Gjedsted, Jens Jørn [person]
# Kaz [person]
# Holm, Benn Q.
# Fogwill, Rodolfo Enrique [person]
# Bessy, Claude [person] ; Track 16 Gallery and Mainspace [organisation]
# Grushkin, Paul D. [person]
# -
# Laing, Dave [person]
# Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]
# Henri, Adrian, 1932- [person] ; Walker, Roger Wade [person]
# Coon, Caroline
# Sams, Gideon
# Seiler, Burkhardt
# Sams, Gideon
# Sams, Gideon
# Poulsen, Henrik Bech [person]
# Poulsen, Henrik Bech [person]
# Turcotte, Bryan Ray [person] ; Miller, Christopher T. [person]
# -
# -
# -
# Savage, Jon [person]
# Levy, Patricia
# Heylin, Clinton [person]
# Rombes, Nicholas [person]
# Milner, Frank [person] ; Walker Art Gallery [organisation] ; Lady Lever Art Gallery [organisation]
# Myers, Benjamin
# Blade, Andy [person]
# -
# -
# -
# Levy, Patricia
# Kogan, Frank
# White, David
# Gordon, Alastair Robert [person] ; Loughborough University [organisation]
# Spicer, Al [person]
# Spicer, Al [person]
# Strongman, Phil [person]
# Mulholland, Garry [person]
# Jones, Preston, 1966- [person] ; Graffin, Greg [person]
# Letts, Don [person] ; Nobakht, David [person]
# Ogg, Alex [person]
# Heylin, Clinton [person]
# Bonds, Jason [person]
# Bennet, Stan [person]
# Sheppard, John [person]
# Cogan, Brian
# Triggs, Teal Ann [person] ; University of Reading [organisation]
# Reddington, Helen [person]
# Traber, Daniel S. [person]
# Reddington, Helen [person] ; University of Westminster [organisation]
# Duncan, Chris [person]
# Benevides, Alyce [person] ; Milles, Jaqueline [person]
# Sladen, Mark [person] ; Yedgar, Ariella [person] ; Barbican Art Gallery [organisation]
# Pozsonyi, Ádám [person]
# Mulholland, Garry [person]
# Wallace, Amy [person] ; Manitoba, Handsome Dick [person]
# Eudeline, Patrick [person]
# Beeber, Steven Lee [person]
# Strongman, Phil [person]
# Heylin, Clinton [person]
# Letts, Don [person] ; Nobakht, David [person]
# Smith, Bobby [person] ; Oshindele-Smith, Margaret, 1966- [person]
# Mason, Matt (Matt James) [person]
# Bourseiller, Christophe
# Bourseiller, Christophe
# Marko, Paul [person]
# Hogg, Brian [person]
# Michalak, Jakub [person]
# Michalak, Jakub [person]
# Michalak, Jakub [person]
# Mattoso, Glauco
# Jandréus, Peter [person]
# -
# -
# Santos, Raye [person] ; McCaffrey, Richard [person] ; Fitzgerald, f-Stop [person] ; Klein, Howie [person]
# Liptrot, Michelle [person]
# Liptrot, Michelle [person]
# -
# Cogan, Brian
# Mathiesen, Trygve
# Komanoya, Rico [person]
# Watson, Gavin [person]
# Waksman, Steve [person]
# Kelley, Trevor [person] ; Simon, Leslie [person]
# Rombes, Nicholas [person]
# Perry, Mark
# -
# Kramer, Fred, 1960- [person] ; Vos, Margot [person]
# Canzonieri, Sal [person]
# Partridge, Christopher Hugh [person]
# Ostow, Micol [person] ; Ostow, David, 1979- [person]
# Beesley, Tony [person]
# Andersen, Mark [person] ; Jenkins, Mark, 1954- [person]
# Boulware, Jack [person] ; Tudor, Silke [person]
# -
# Belmont, Ant [person]
# Gopegui, Belén
# Logan, Simon [person]
# Davidson, Eric
# Kristiansen, Lars J.
# Vee, Tesco [person] ; Stimson, Dave [person] ; Miller, Steve [person]
# Carlson, Zack [person] ; Connolly, Bryan [person]
# Roach, Martin
# Cogan, Brian
# Chrome, Cheetah [person]
# Tulien, Sean [person] ; Aburto, Jesus [person]
# Penner, James
# Leigh, Mickey [person] ; McNeil, Legs [person]
# González, Mariño
# Morton, Jennifer
# Williamson, Aaron [person] ; Wright, Adam [person] ; Collins, Tony [person]
# Williamson, Aaron [person] ; Wright, Adam [person] ; Collins, Tony [person]
# Watkins, Matt, editor [person] ; Inglefield, Mark, editor [person] ; Haunch of Venison (Gallery), publisher [organisation]
# Pyle, Don [person]
# McMurray, Jacob [person] ; Experience Music Project [organisation]
# Hill, Tony [person]
# Reddington, Helen [person]
# Bag, Alice [person]
# -
# Rimmer, Dave [person]
# San Miguel, Dolores [person]
# Hidalgo, Daniel
# Kamikaze Factory Studio [organisation]
# Dale, Pete R. W. [person] ; University of Newcastle upon Tyne [organisation]
# Stewart, Francis Elizabeth [person] ; University of Stirling [organisation]
# Glasper, Ian [person]
# -
# Dale, Pete [person]
# Sanderson, Punk
# Bestley, Russell [person] ; Ogg, Alex [person]
# Kerr, Joe, 1958-, editor [person] ; Gibson, Andrew, 1949-, editor [person]
# Poulsen, Henrik Bech [person]
# Poulsen, Henrik Bech [person]
# Ebersole, Stewart Dean [person] ; Castaldi, Jared [person]
# Flores, Daniel
# Seven, John [person] ; Christy, Jana [person]
# Johnson, Mark [person] ; University of St. Andrews [organisation]
# Mott, Toby [person]
# Ensminger, David A. [person]
# Biel, Joe [person]
# Markey, Dave, 1963- [person] ; Schwartz, Jordan [person]
# Harvey, Paul, author [person] ; University of Northumbria at Newcastle [organisation]
# Matthews, John, 1948- [person] ; Matthews, Caitkin [person] ; Kinghan, Wil [person]
# Mitchell, Max
# Belk, Martin
# Anniss, Matt
# Singleton, David, 1961-, author [person] ; Singleton, Ben, artist, cartoonist [person] ; Sanderson, Punk [person]
# Savage, Jon, editor, interviewer [person] ; Baker, Stuart, editor, interviewer, writer [person] ; Reid, Jamie, 1947-, writer [person] ; Vaucher, Gee, writer [person]
# Savage, Jon, editor, interviewer [person] ; Baker, Stuart, editor, interviewer, writer [person] ; Reid, Jamie, 1947-, writer [person] ; Vaucher, Gee, writer [person]
# Savage, Jon, editor, interviewer [person] ; Baker, Stuart, editor, interviewer, writer [person] ; Reid, Jamie, 1947-, writer [person] ; Vaucher, Gee, writer [person]
# Pussy Riot (Musical group)
# Kulesza, Piotr [person]
# Cross, Daniel, Documentary filmmaker [person] ; Roach [person]
# Du Noyer, Paul
# PunkPistol
# Ricketson, Kathreen
# Daft Punk (Musical group) [organisation]
# Daft Punk (Musical group) [organisation]
# Ashton-Smith, Alan, author [person] ; Birkbeck College [organisation]
# Ploeg, Joshua
# Raposo, Ana Bastos, author [person] ; University of the Arts London [organisation]
# Suterwalla, Shehnaz, author [person] ; Royal College of Art (Great Britain) [organisation]
# Davidson, Nick
# Coles, Tait
# Rohrer, Ingo
# Santorelli, Dina
# Hein, Fabien [person]
# Santorelli, Dina
# Pescetelli, Claudio [person]
# Glasper, Ian
# Sullivan, Kevin
# Collins, Bob
# Bonello Rutter Giappone, Krista, author [person] ; University of Kent [organisation]
# Stein, Chris
# Bestley, Russell, author [person] ; Ogg, Alex, author [person]
# Sutu, artist, author [person] ; Love Punks (Organization) [organisation]
# Loughridge, Lee
# Loughridge, Lee
# Wendell, Eric
# Crossley, Nick
# Sutu, artist, author [person] ; Love Punks (Organization) [organisation]
# Ryde, Robin [person] ; Sofianos, Lisa [person] ; Waterhouse, Charlie [person]
# Taylor, Raven
# Hannerz, Erik [person]
# Sutu, artist, author [person] ; Love Punks (Organization) [organisation]
# Laing, Dave
# Sang, Anthony
# Sang, Anthony
# -
# Panic, Paul
# Slight, Sally Ann
# Bucayu, Mike, editor [person] ; Driesler, Steve, editor [person] ; Furnish, Timothy, editor [person]
# Matheson, Andrew
# Matheson, Andrew
# Laing, Dave
# -
# Himelstein, Abram Shalom, author [person] ; Schweser, Jamie, author [person]
# Davis, Guy, 1966-, author [person] ; Reed, Gary, 1956-, author [person]
# Green Scum, 1962-, author [person] ; Bux, Lucie, illustrator [person]
# Suren, Bob
# Strasser, Axel
# Lazarov, Dale, artist [person] ; Mariotti, Mauro, artist [person] ; Janecki, Janos, artist [person]
# Torres, David G.
# Torres, David G.
# Sang, Anthony
# Grushkin, Paul
# Makagon, Daniel
# Silva, Augusto Santos, 1956- [person] ; Guerra, Paula [person]
# Coyote, Ginger [person]
# Coyote, Ginger [person]
# Watt, James
# Mattioli, Heath, author [person] ; Spacone, David, author [person]
# Watt, James
# King, John
# Ryde, Robin [person]
# Hannerz, Erik
# Hurchalla, George
# McCabe, Ste
# Savage, Jon
# -
# King, John
# Xiao, Jian, author [person] ; Loughborough University [organisation]
# -
# Phillips, Jason
# Pascual, Jakue
# Dunn, Kevin C.
# Ferrarese, Marco
# Croland, Michael
# Torcinovich, Matteo, author [person] ; Girardi, Sebastiano, author [person]
# Lohman, Kirsty, author [person] ; University of Warwick [organisation]
# Doe, John, 1954-, author, editor [person] ; DeSavia, Tom, author, editor [person]
# Bunn, Cullen, author [person] ; Cm Punk, 1978-, author [person] ; Hepburn, Scott, artist [person]
# Dale, Pete
# Smith, Slim [person]
# Hurchalla, George
# Matheson, Andrew
# Gonzales, Michelle Cruz
# Dunn, Kevin C.
# Gonzales, Michelle Cruz
# Narita, Ryōgo, 1980-, author [person] ; Enami, Katsumi, illustrator [person]
# Narita, Ryōgo, 1980-, author [person] ; Enami, Katsumi, illustrator [person]

# %% [markdown]
# Our code since now looks like the following listing. Now we deal with both single authors and groups of authors. We clean texts by using *re*, a module that provides few functions to modify strings on the basis of some pattern.
#
# `re.sub` method accepts three arguments:
#  * the pattern to be replaced
#  * the string that replaces the former
#  * the string where to apply such a replacement.
#
# Analyse the following patterns:
#
# `\s?[\(\[].*?[\)\]]\s?`
#
#  * `\s` matches any whitespace character;
#  * `\s?` matches an optional whitespace (it might be there or not). We consider it both at the beginning and at the end of a string;
#  * `[\(\[]` the outer squared barckets include a group of matching strings: this is the pattern that we want to substitute with "" (an empty string). The group includes both ( and \[, that are escaped (i.e., since \[\] normally wrap groups of matching strings, we add a slash before the characters so that the interpreter matches the characters ( and [ literally).
#  * `[\)\]]` similarly to the prior one, this matches the outer parenthesis in our string.
#  * `.` matches any character (in this case, any character included in either () or \[\]); `.*?` quantifies the number of possible characters between 0 and unlimited (so that we don't care about the actual content of parenthesis)
#
# `\,?\s?\d+\-?`
#
#  * `\,?`, `\-?` matche optional characters ',' and '-'
#  * `\d+` matches one or more digits (numbers)

# %%
for auth in authors:   
    auth = re.sub("\s?[\(\[].*?[\)\]]\s?", "", auth) # remove [], () and text included 
    auth = re.sub("\,?\s?\d+\-?", "", auth) # remove digits and if exist, following - and  preceding ','
    auth = re.sub(';',',',auth) # finally remove the ;
    auth = auth+'.' # rebuild the final string and add a dot in the end
# Out:
# Evans, Mike.
# Jones, Steven.
# Marcus, Greil.
# Gibbon, Peter, Centret for udviklingsforskning.
# Butler, Chris.
# Mulholland, Garry.
# Wright, Peter Poyntz.
# Wells, Steven.
# Jasper, Maura, Mancini, Hilken.
# McGuirk, Niall.
# Ercoli, Rikki.
# Jocoy, Jim, Moore, Thurston, Cervenka, Exene.
# Walsh, Gavin.
# King, John.
# Cannon, Brian John Matthew.
# Bayley, Roberta.
# Bockris, Victor.
# Rocco, John.
# McIver, Joel.
# Anscombe, Isabelle.
# O'Regan, Denis.
# Belsito, Peter, Davis, Bob, Kester, Marion.
# Leblanc, Lauraine.
# Alexandersson, Gunvor, Lundquist, Lena.
# Teipel, Jürgen.
# Ogram, patippu.
# Kerr, Joe, Gibson, Andrew.
# Caiafa, Janicł.
# Stevenson, Nils, Stevenson, Ray.
# O'Hara, Craig.
# O'Hara, Craig.
# Vague, Tom.
# Fielding, Garry.
# Home, Stewart.
# Zimmermann, Peter, writer.
# May, Michael.
# Coon, Caroline.
# .
# King, John.
# Andersen, Mark, Jenkins, Mark.
# Craine, Nick, Turner, Michael, MacDonald, Bruce.
# Craine, Nick, Turner, Michael, MacDonald, Bruce.
# Carr, Emily.
# Carr, Emily.
# Mulholland, Garry.
# McNeil, Legs, McCain, Gillian.
# Steel, Mark.
# Davis, Guy, Reed, Gary.
# Dellar, Robert.
# Sams, Gideon.
# McLaren, Louise.
# Aizlewood, John, Collins, Andrew, Prince, Bill.
# Aizlewood, John, Collins, Andrew, Prince, Bill.
# Helander, Brock.
# Laing, Dave.
# McNeil, Legs, McCain, Gillian.
# Sabin, Roger.
# Rimmer, Dave.
# Savage, Jon.
# Perry, Mark, vocalist, Rawlings, Terry.
# Roach, Martin.
# Joynson, Vernon.
# Taylor, Steven.
# Hayward, Philip, editor.
# .
# .
# Savage, Jon.
# Savage, Jon.
# Russell, Bill.
# O'Connell, Terry.
# Wright, Peter Poyntz.
# Dickson, Ian.
# Grushkin, Paul D..
# Sex Pistols.
# Heubner, Thomas.
# Carroll, Jessica, Smith, Craig.
# Henri, Adrian, Walker, Roger Wade.
# Echenberg, Erica, P., Mark.
# Coon, Caroline.
# Marcus, Greil.
# Chidolue, Dagmar, Mathieu, François.
# Gjedsted, Jens Jørn.
# Kaz.
# Holm, Benn Q..
# Fogwill, Rodolfo Enrique.
# Bessy, Claude, Track Gallery and Mainspace.
# Grushkin, Paul D..
# .
# Laing, Dave.
# Andersen, Mark, Jenkins, Mark.
# Henri, Adrian, Walker, Roger Wade.
# Coon, Caroline.
# Sams, Gideon.
# Seiler, Burkhardt.
# Sams, Gideon.
# Sams, Gideon.
# Poulsen, Henrik Bech.
# Poulsen, Henrik Bech.
# Turcotte, Bryan Ray, Miller, Christopher T..
# .
# .
# .
# Savage, Jon.
# Levy, Patricia.
# Heylin, Clinton.
# Rombes, Nicholas.
# Milner, Frank, Walker Art Gallery, Lady Lever Art Gallery.
# Myers, Benjamin.
# Blade, Andy.
# .
# .
# .
# Levy, Patricia.
# Kogan, Frank.
# White, David.
# Gordon, Alastair Robert, Loughborough University.
# Spicer, Al.
# Spicer, Al.
# Strongman, Phil.
# Mulholland, Garry.
# Jones, Preston, Graffin, Greg.
# Letts, Don, Nobakht, David.
# Ogg, Alex.
# Heylin, Clinton.
# Bonds, Jason.
# Bennet, Stan.
# Sheppard, John.
# Cogan, Brian.
# Triggs, Teal Ann, University of Reading.
# Reddington, Helen.
# Traber, Daniel S..
# Reddington, Helen, University of Westminster.
# Duncan, Chris.
# Benevides, Alyce, Milles, Jaqueline.
# Sladen, Mark, Yedgar, Ariella, Barbican Art Gallery.
# Pozsonyi, Ádám.
# Mulholland, Garry.
# Wallace, Amy, Manitoba, Handsome Dick.
# Eudeline, Patrick.
# Beeber, Steven Lee.
# Strongman, Phil.
# Heylin, Clinton.
# Letts, Don, Nobakht, David.
# Smith, Bobby, Oshindele-Smith, Margaret.
# Mason, Matt.
# Bourseiller, Christophe.
# Bourseiller, Christophe.
# Marko, Paul.
# Hogg, Brian.
# Michalak, Jakub.
# Michalak, Jakub.
# Michalak, Jakub.
# Mattoso, Glauco.
# Jandréus, Peter.
# .
# .
# Santos, Raye, McCaffrey, Richard, Fitzgerald, f-Stop, Klein, Howie.
# Liptrot, Michelle.
# Liptrot, Michelle.
# .
# Cogan, Brian.
# Mathiesen, Trygve.
# Komanoya, Rico.
# Watson, Gavin.
# Waksman, Steve.
# Kelley, Trevor, Simon, Leslie.
# Rombes, Nicholas.
# Perry, Mark, vocalist.
# .
# Kramer, Fred, Vos, Margot.
# Canzonieri, Sal.
# Partridge, Christopher Hugh.
# Ostow, Micol, Ostow, David.
# Beesley, Tony.
# Andersen, Mark, Jenkins, Mark.
# Boulware, Jack, Tudor, Silke.
# .
# Belmont, Ant.
# Gopegui, Belén.
# Logan, Simon.
# Davidson, Eric, singer.
# Kristiansen, Lars J..
# Vee, Tesco, Stimson, Dave, Miller, Steve.
# Carlson, Zack, Connolly, Bryan.
# Roach, Martin.
# Cogan, Brian.
# Chrome, Cheetah.
# Tulien, Sean, Aburto, Jesus.
# Penner, James.
# Leigh, Mickey, McNeil, Legs.
# González, Mariño.
# Morton, Jennifer.
# Williamson, Aaron, Wright, Adam, Collins, Tony.
# Williamson, Aaron, Wright, Adam, Collins, Tony.
# Watkins, Matt, editor, Inglefield, Mark, editor, Haunch of Venison, publisher.
# Pyle, Don.
# McMurray, Jacob, Experience Music Project.
# Hill, Tony.
# Reddington, Helen.
# Bag, Alice.
# .
# Rimmer, Dave.
# San Miguel, Dolores.
# Hidalgo, Daniel.
# Kamikaze Factory Studio.
# Dale, Pete R. W., University of Newcastle upon Tyne.
# Stewart, Francis Elizabeth, University of Stirling.
# Glasper, Ian.
# .
# Dale, Pete.
# Sanderson, Punk, author.
# Bestley, Russell, Ogg, Alex.
# Kerr, Joe, editor, Gibson, Andrew, editor.
# Poulsen, Henrik Bech.
# Poulsen, Henrik Bech.
# Ebersole, Stewart Dean, Castaldi, Jared.
# Flores, Daniel, author, writer.
# Seven, John, Christy, Jana.
# Johnson, Mark, University of St. Andrews.
# Mott, Toby.
# Ensminger, David A..
# Biel, Joe.
# Markey, Dave, Schwartz, Jordan.
# Harvey, Paul, author, University of Northumbria at Newcastle.
# Matthews, John, Matthews, Caitkin, Kinghan, Wil.
# Mitchell, Max, author, writer.
# Belk, Martin, author.
# Anniss, Matt, author.
# Singleton, David, author, Singleton, Ben, artist, cartoonist, Sanderson, Punk.
# Savage, Jon, editor, interviewer, Baker, Stuart, editor, interviewer, writer, Reid, Jamie, writer, Vaucher, Gee, writer.
# Savage, Jon, editor, interviewer, Baker, Stuart, editor, interviewer, writer, Reid, Jamie, writer, Vaucher, Gee, writer.
# Savage, Jon, editor, interviewer, Baker, Stuart, editor, interviewer, writer, Reid, Jamie, writer, Vaucher, Gee, writer.
# Pussy Riot, author.
# Kulesza, Piotr.
# Cross, Daniel, Documentary filmmaker, Roach.
# Du Noyer, Paul, author.
# PunkPistol, author.
# Ricketson, Kathreen, author.
# Daft Punk.
# Daft Punk.
# Ashton-Smith, Alan, author, Birkbeck College.
# Ploeg, Joshua, author.
# Raposo, Ana Bastos, author, University of the Arts London.
# Suterwalla, Shehnaz, author, Royal College of Art.
# Davidson, Nick, approximately, author.
# Coles, Tait, author.
# Rohrer, Ingo, author.
# Santorelli, Dina, author.
# Hein, Fabien.
# Santorelli, Dina, author.
# Pescetelli, Claudio.
# Glasper, Ian, author.
# Sullivan, Kevin, author.
# Collins, Bob, author.
# Bonello Rutter Giappone, Krista, author, University of Kent.
# Stein, Chris, author, photographer.
# Bestley, Russell, author, Ogg, Alex, author.
# Sutu, artist, author, Love Punks.
# Loughridge, Lee, editor.
# Loughridge, Lee, editor.
# Wendell, Eric, author.
# Crossley, Nick, author.
# Sutu, artist, author, Love Punks.
# Ryde, Robin, Sofianos, Lisa, Waterhouse, Charlie.
# Taylor, Raven, author.
# Hannerz, Erik.
# Sutu, artist, author, Love Punks.
# Laing, Dave, author.
# Sang, Anthony, artist, author.
# Sang, Anthony, artist, author.
# .
# Panic, Paul, author.
# Slight, Sally Ann, author.
# Bucayu, Mike, editor, Driesler, Steve, editor, Furnish, Timothy, editor.
# Matheson, Andrew, author.
# Matheson, Andrew, author.
# Laing, Dave, author.
# .
# Himelstein, Abram Shalom, author, Schweser, Jamie, author.
# Davis, Guy, author, Reed, Gary, author.
# Green Scum, author, Bux, Lucie, illustrator.
# Suren, Bob, author.
# Strasser, Axel, author.
# Lazarov, Dale, artist, Mariotti, Mauro, artist, Janecki, Janos, artist.
# Torres, David G., editor, writer.
# Torres, David G., editor, writer.
# Sang, Anthony, artist, author.
# Grushkin, Paul, author.
# Makagon, Daniel, author.
# Silva, Augusto Santos, Guerra, Paula.
# Coyote, Ginger.
# Coyote, Ginger.
# Watt, James, Founder of BrewDog, author.
# Mattioli, Heath, author, Spacone, David, author.
# Watt, James, Founder of BrewDog, author.
# King, John, author.
# Ryde, Robin.
# Hannerz, Erik, author.
# Hurchalla, George, author.
# McCabe, Ste, author.
# Savage, Jon, author.
# .
# King, John, author.
# Xiao, Jian, author, Loughborough University.
# .
# Phillips, Jason.
# Pascual, Jakue, author.
# Dunn, Kevin C., author.
# Ferrarese, Marco, author.
# Croland, Michael, author.
# Torcinovich, Matteo, author, Girardi, Sebastiano, author.
# Lohman, Kirsty, author, University of Warwick.
# Doe, John, author, editor, DeSavia, Tom, author, editor.
# Bunn, Cullen, author, Cm Punk, author, Hepburn, Scott, artist.
# Dale, Pete, author.
# Smith, Slim.
# Hurchalla, George, author.
# Matheson, Andrew, author.
# Gonzales, Michelle Cruz, author.
# Dunn, Kevin C., author.
# Gonzales, Michelle Cruz, author.
# Narita, Ryōgo, author, Enami, Katsumi, illustrator.
# Narita, Ryōgo, author, Enami, Katsumi, illustrator.

# %% [markdown]
# Here below is listed the entire code of our function, that we called 'cleanAuthors', with arguments *inputFile* and *fieldName*:

# %%
def cleanAuthors(inputFile, fieldName):
    ''' given a list of authors in the form lastName, firstName 
    returns the same list cleaned and ready to be integrated in a bibliographic citation in Chicago style'''
    authors , cleanAuthorsList = [] , [] # create a list with authors, prepare the list to store the cleaned list of authors

    with open(inputFile, 'r', errors='ignore') as csvfile:
        reader = csv.DictReader(csvfile)
        authors = [row[fieldName] for row in reader] # we used list comprehension to make it short
    
    for auth in authors: 
        if ';' in auth:      
            splitList = auth.split(';') # split a group of authors by semicolon
            splitList = [au for au in splitList if 'organisation' not in au] # remove organizations from the list of authors
            for au in splitList: # iterate over each author in a group
                splitList2 = au.split(',') # split parts of the name of a single author by comma
                if len(splitList2) >=3: # after removing organisations, if there are still more than one author
                    del splitList2[2:] # delete the substring after the third comma if exists (e.g. author, writer)
                    splitList = [auth.replace(au, ', '.join(aux.strip() for aux in splitList2))] 
                if (len(splitList2) == 2) and ('artist' in splitList2[1] or 'author' in splitList2[1]) : # delete artist when in second position
                    del splitList2[1]
                    splitList = splitList2 # delete role when there is only the name of art
                auth = ';'.join(au for au in splitList if au != ' ') # rebuild the string

            splitList = auth.split(';')  # split again the string to swap names
            if len(splitList) >= 2: # when there is more than one author
                for i in splitList[0]: # deal with the first author 
                    i = i.strip() # remove whitespace in the first author's name
                for i in splitList[1:]: # deal with all the other authors' names 
                    if ',' in i: 
                        splitList2 = i.split(',') # split each author's name by comma
                        splitList2[0], splitList2[1] = splitList2[1], splitList2[0] # swap last name and first name
                        splitList = [auth.replace(i, ' '.join(i for i in splitList2))] # rebuild the list of names
                        auth = ', '.join(au for au in splitList if au != ' ') # rebuild the list of authors

                splitList = auth.split(';') # split again the (updated) list of multiple authors
                splitList[-1] = str(' and'+splitList[-1]) # add "and" before the last author, after swapping last/first name
                auth = ';'.join(au for au in splitList if au != ' ') # update the list again

        else:
            splitList = auth.split(',') # split parts of the name of a single author by comma
            if len(splitList) >=3:
                del splitList[2:]
                splitList = [auth.replace(auth, ', '.join(aux.strip() for aux in splitList))]
            if (len(splitList) == 2) and ('artist' in splitList[1] or 'author' in splitList[1]) : # delete artist when in second position
                del splitList[1]
            auth = ','.join(au for au in splitList)
        if len(auth) == 0: # substitutes empty authors with -
            auth = '-'
            
        auth = re.sub("\s?[\(\[].*?[\)\]]\s?", "", auth) # remove [], () and text included 
        auth = re.sub("\,?\s?\d+\-?", "", auth) # remove digits and if exist, following - and  preceding ','
        auth = re.sub(';',',',auth) # finally remove the ;
        auth = auth+'.' # rebuild the final string and add a dot in the end
        
        cleanAuthorsList.append(auth)
    
    return cleanAuthorsList

# %%
cleanAuthors('titles.csv', 'All names')
# Out:
# ['Evans, Mike.',
#  'Jones, Steven.',
#  'Marcus, Greil.',
#  'Gibbon, Peter.',
#  'Butler, Chris.',
#  'Mulholland, Garry.',
#  'Wright, Peter Poyntz.',
#  'Wells, Steven.',
#  'Jasper, Maura, and Hilken Mancini.',
#  'McGuirk, Niall.',
#  'Ercoli, Rikki.',
#  'Jocoy, Jim, Thurston  Moore, and Exene Cervenka.',
#  'Walsh, Gavin.',
#  'King, John.',
#  'Cannon, Brian John Matthew.',
#  'Bayley, Roberta.',
#  'Bockris, Victor.',
#  'Rocco, John.',
#  'McIver, Joel.',
#  'Anscombe, Isabelle.',
#  "O'Regan, Denis.",
#  'Belsito, Peter, Bob  Davis, and Marion Kester.',
#  'Leblanc, Lauraine.',
#  'Alexandersson, Gunvor, and Lena Lundquist.',
#  'Teipel, Jürgen.',
#  'Ogram, patippu.',
#  'Kerr, Joe, and Andrew Gibson.',
#  'Caiafa, Janicł.',
#  'Stevenson, Nils, and Ray Stevenson.',
#  "O'Hara, Craig.",
#  "O'Hara, Craig.",
#  'Vague, Tom.',
#  'Fielding, Garry.',
#  'Home, Stewart.',
#  'Zimmermann, Peter.',
#  'May, Michael.',
#  'Coon, Caroline.',
#  '-.',
#  'King, John.',
#  'Andersen, Mark, and Mark Jenkins.',
#  'Craine, Nick, Michael Turner, and Bruce MacDonald.',
#  'Craine, Nick, Michael Turner, and Bruce MacDonald.',
#  'Carr, Emily.',
#  'Carr, Emily.',
#  'Mulholland, Garry.',
#  'McNeil, Legs, and Gillian McCain.',
#  'Steel, Mark.',
#  'Davis, Guy, and Gary Reed.',
#  'Dellar, Robert.',
#  'Sams, Gideon.',
#  'McLaren, Louise.',
#  'Aizlewood, John, Andrew Collins, and Bill Prince.',
#  'Aizlewood, John, Andrew Collins, and Bill Prince.',
#  'Helander, Brock.',
#  'Laing, Dave.',
#  'McNeil, Legs, and Gillian McCain.',
#  'Sabin, Roger.',
#  'Rimmer, Dave.',
#  'Savage, Jon.',
#  'Perry, Mark, and Terry Rawlings.',
#  'Roach, Martin.',
#  'Joynson, Vernon.',
#  'Taylor, Steven.',
#  'Hayward, Philip.',
#  '-.',
#  '-.',
#  'Savage, Jon.',
#  'Savage, Jon.',
#  'Russell, Bill.',
#  "O'Connell, Terry.",
#  'Wright, Peter Poyntz.',
#  'Dickson, Ian.',
#  'Grushkin, Paul D..',
#  'Sex Pistols.',
#  'Heubner, Thomas.',
#  'Carroll, Jessica, and Craig Smith.',
#  'Henri, Adrian, and Roger Wade Walker.',
#  'Echenberg, Erica, and Mark P..',
#  'Coon, Caroline.',
#  'Marcus, Greil.',
#  'Chidolue, Dagmar, and François Mathieu.',
#  'Gjedsted, Jens Jørn.',
#  'Kaz.',
#  'Holm, Benn Q..',
#  'Fogwill, Rodolfo Enrique.',
#  'Bessy, Claude.',
#  'Grushkin, Paul D..',
#  '-.',
#  'Laing, Dave.',
#  'Andersen, Mark, and Mark Jenkins.',
#  'Henri, Adrian, and Roger Wade Walker.',
#  'Coon, Caroline.',
#  'Sams, Gideon.',
#  'Seiler, Burkhardt.',
#  'Sams, Gideon.',
#  'Sams, Gideon.',
#  'Poulsen, Henrik Bech.',
#  'Poulsen, Henrik Bech.',
#  'Turcotte, Bryan Ray, and Christopher T. Miller.',
#  '-.',
#  '-.',
#  '-.',
#  'Savage, Jon.',
#  'Levy, Patricia.',
#  'Heylin, Clinton.',
#  'Rombes, Nicholas.',
#  'Milner, Frank.',
#  'Myers, Benjamin.',
#  'Blade, Andy.',
#  '-.',
#  '-.',
#  '-.',
#  'Levy, Patricia.',
#  'Kogan, Frank.',
#  'White, David.',
#  'Gordon, Alastair Robert.',
#  'Spicer, Al.',
#  'Spicer, Al.',
#  'Strongman, Phil.',
#  'Mulholland, Garry.',
#  'Jones, Preston, and Greg Graffin.',
#  'Letts, Don, and David Nobakht.',
#  'Ogg, Alex.',
#  'Heylin, Clinton.',
#  'Bonds, Jason.',
#  'Bennet, Stan.',
#  'Sheppard, John.',
#  'Cogan, Brian.',
#  'Triggs, Teal Ann.',
#  'Reddington, Helen.',
#  'Traber, Daniel S..',
#  'Reddington, Helen.',
#  'Duncan, Chris.',
#  'Benevides, Alyce, and Jaqueline Milles.',
#  'Sladen, Mark, and Ariella  Yedgar.',
#  'Pozsonyi, Ádám.',
#  'Mulholland, Garry.',
#  'Wallace, Amy, and Handsome Dick Manitoba.',
#  'Eudeline, Patrick.',
#  'Beeber, Steven Lee.',
#  'Strongman, Phil.',
#  'Heylin, Clinton.',
#  'Letts, Don, and David Nobakht.',
#  'Smith, Bobby, and Margaret Oshindele-Smith.',
#  'Mason, Matt.',
#  'Bourseiller, Christophe.',
#  'Bourseiller, Christophe.',
#  'Marko, Paul.',
#  'Hogg, Brian.',
#  'Michalak, Jakub.',
#  'Michalak, Jakub.',
#  'Michalak, Jakub.',
#  'Mattoso, Glauco.',
#  'Jandréus, Peter.',
#  '-.',
#  '-.',
#  'Santos, Raye, Richard  McCaffrey, f-Stop  Fitzgerald, and Howie Klein.',
#  'Liptrot, Michelle.',
#  'Liptrot, Michelle.',
#  '-.',
#  'Cogan, Brian.',
#  'Mathiesen, Trygve.',
#  'Komanoya, Rico.',
#  'Watson, Gavin.',
#  'Waksman, Steve.',
#  'Kelley, Trevor, and Leslie Simon.',
#  'Rombes, Nicholas.',
#  'Perry, Mark.',
#  '-.',
#  'Kramer, Fred, and Margot Vos.',
#  'Canzonieri, Sal.',
#  'Partridge, Christopher Hugh.',
#  'Ostow, Micol, and David Ostow.',
#  'Beesley, Tony.',
#  'Andersen, Mark, and Mark Jenkins.',
#  'Boulware, Jack, and Silke Tudor.',
#  '-.',
#  'Belmont, Ant.',
#  'Gopegui, Belén.',
#  'Logan, Simon.',
#  'Davidson, Eric.',
#  'Kristiansen, Lars J..',
#  'Vee, Tesco, Dave  Stimson, and Steve Miller.',
#  'Carlson, Zack, and Bryan Connolly.',
#  'Roach, Martin.',
#  'Cogan, Brian.',
#  'Chrome, Cheetah.',
#  'Tulien, Sean, and Jesus Aburto.',
#  'Penner, James.',
#  'Leigh, Mickey, and Legs McNeil.',
#  'González, Mariño.',
#  'Morton, Jennifer.',
#  'Williamson, Aaron, Adam  Wright, and Tony Collins.',
#  'Williamson, Aaron, Adam  Wright, and Tony Collins.',
#  'Watkins, Matt, Mark Inglefield, and publisher Haunch of Venison.',
#  'Pyle, Don.',
#  'McMurray, Jacob.',
#  'Hill, Tony.',
#  'Reddington, Helen.',
#  'Bag, Alice.',
#  '-.',
#  'Rimmer, Dave.',
#  'San Miguel, Dolores.',
#  'Hidalgo, Daniel.',
#  'Kamikaze Factory Studio.',
#  'Dale, Pete R. W..',
#  'Stewart, Francis Elizabeth.',
#  'Glasper, Ian.',
#  '-.',
#  'Dale, Pete.',
#  'Sanderson, Punk.',
#  'Bestley, Russell, and Alex Ogg.',
#  'Kerr, Joe, and Andrew Gibson.',
#  'Poulsen, Henrik Bech.',
#  'Poulsen, Henrik Bech.',
#  'Ebersole, Stewart Dean, and Jared Castaldi.',
#  'Flores, Daniel.',
#  'Seven, John, and Jana Christy.',
#  'Johnson, Mark.',
#  'Mott, Toby.',
#  'Ensminger, David A..',
#  'Biel, Joe.',
#  'Markey, Dave, and Jordan Schwartz.',
#  'Harvey, Paul, and University of Northumbria at Newcastle.',
#  'Matthews, John, Caitkin  Matthews, and Wil Kinghan.',
#  'Mitchell, Max.',
#  'Belk, Martin.',
#  'Anniss, Matt.',
#  'Singleton, David, Ben Singleton, and Punk Sanderson.',
#  'Savage, Jon, Stuart Baker, Jamie Reid, and Gee Vaucher.',
#  'Savage, Jon, Stuart Baker, Jamie Reid, and Gee Vaucher.',
#  'Savage, Jon, Stuart Baker, Jamie Reid, and Gee Vaucher.',
#  'Pussy Riot.',
#  'Kulesza, Piotr.',
#  'Cross, Daniel, and Roach.',
#  'Du Noyer, Paul.',
#  'PunkPistol.',
#  'Ricketson, Kathreen.',
#  'Daft Punk.',
#  'Daft Punk.',
#  'Ashton-Smith, Alan, and Birkbeck College.',
#  'Ploeg, Joshua.',
#  'Raposo, Ana Bastos, and University of the Arts London.',
#  'Suterwalla, Shehnaz, and Royal College of Art.',
#  'Davidson, Nick.',
#  'Coles, Tait.',
#  'Rohrer, Ingo.',
#  'Santorelli, Dina.',
#  'Hein, Fabien.',
#  'Santorelli, Dina.',
#  'Pescetelli, Claudio.',
#  'Glasper, Ian.',
#  'Sullivan, Kevin.',
#  'Collins, Bob.',
#  'Bonello Rutter Giappone, Krista, and University of Kent.',
#  'Stein, Chris.',
#  'Bestley, Russell, and Alex Ogg.',
#  'Sutu.',
#  'Loughridge, Lee.',
#  'Loughridge, Lee.',
#  'Wendell, Eric.',
#  'Crossley, Nick.',
#  'Sutu.',
#  'Ryde, Robin, Lisa  Sofianos, and Charlie Waterhouse.',
#  'Taylor, Raven.',
#  'Hannerz, Erik.',
#  'Sutu.',
#  'Laing, Dave.',
#  'Sang, Anthony.',
#  'Sang, Anthony.',
#  '-.',
#  'Panic, Paul.',
#  'Slight, Sally Ann.',
#  'Bucayu, Mike, Steve Driesler, and Timothy Furnish.',
#  'Matheson, Andrew.',
#  'Matheson, Andrew.',
#  'Laing, Dave.',
#  '-.',
#  'Himelstein, Abram Shalom, and Jamie Schweser.',
#  'Davis, Guy, and Gary Reed.',
#  'Green Scum, and Lucie Bux.',
#  'Suren, Bob.',
#  'Strasser, Axel.',
#  'Lazarov, Dale, Mauro Mariotti, and Janos Janecki.',
#  'Torres, David G..',
#  'Torres, David G..',
#  'Sang, Anthony.',
#  'Grushkin, Paul.',
#  'Makagon, Daniel.',
#  'Silva, Augusto Santos, and Paula Guerra.',
#  'Coyote, Ginger.',
#  'Coyote, Ginger.',
#  'Watt, James.',
#  'Mattioli, Heath, and David Spacone.',
#  'Watt, James.',
#  'King, John.',
#  'Ryde, Robin.',
#  'Hannerz, Erik.',
#  'Hurchalla, George.',
#  'McCabe, Ste.',
#  'Savage, Jon.',
#  '-.',
#  'King, John.',
#  'Xiao, Jian, and Loughborough University.',
#  '-.',
#  'Phillips, Jason.',
#  'Pascual, Jakue.',
#  'Dunn, Kevin C..',
#  'Ferrarese, Marco.',
#  'Croland, Michael.',
#  'Torcinovich, Matteo, and Sebastiano Girardi.',
#  'Lohman, Kirsty, and University of Warwick.',
#  'Doe, John, and Tom DeSavia.',
#  'Bunn, Cullen, Cm Punk, and Scott Hepburn.',
#  'Dale, Pete.',
#  'Smith, Slim.',
#  'Hurchalla, George.',
#  'Matheson, Andrew.',
#  'Gonzales, Michelle Cruz.',
#  'Dunn, Kevin C..',
#  'Gonzales, Michelle Cruz.',
#  'Narita, Ryōgo, and Katsumi Enami.',
#  'Narita, Ryōgo, and Katsumi Enami.']

# %% [markdown]
# Now we finally have the cleaned list of authors we need. We can move forward and create the function to print our bibliographic citation in Chicago Style. We call it **chicagoCitation** and we ask as arguments:
#
#  * a csv file
#  * all the fieldnames we need to retrieve: authors, title, city, publisher, and date of publishing
#
# We behave as we know, namely:
#  * open a csv file
#  * call the function we created to clean authors' names and fill a new list called *authorsList*
#  * create empty lists to store values of required fields
#  * iterate over rows of the csv and fill the aforementioned lists
#
# Then we collate the lists we created by using the **zip()** function. It iterates over every list we include as argument, and creates a tuple for each match. In order to query a zip object, we transform it in a list.
#
# Finally we can iterate over items of the latter list and build our citation. Since both the publisher and the city might not appear in original data for some records, we define two situations (with and without the publisher). In our tuples the publisher is always the fourth item (*citation\[3\]*): when this equals '', we avoid to print that value and skip directly to the date. Otherwise we print the complete reference.

# %%
import csv 
def chicagoCitation(inputFile, authors, title, city, publisher, date):
    ''' given a csv file and fieldnames including all the elements of a bibliographic reference 
    returns the bibliographic citation in Chicago style'''

    with open(inputFile, 'r', errors='ignore') as csvfile:
        authorsList = cleanAuthors(inputFile, authors)
        titlesList , citiesList , publishersList , datesList = [] , [] , [] , [] # create lists
        reader = csv.DictReader(csvfile)
        for row in reader: 
            titlesList.append(row[title])
            citiesList.append(row[city])
            publishersList.append(row[publisher])
            datesList.append(row[date])
        
        citations = list(zip(authorsList, titlesList, citiesList, publishersList, datesList))
        for citation in citations:
            if citation[3] is '':
                print(citation[0]+' '+citation[1]+'. '+citation[4]+'.')
            else:
                print(citation[0]+' '+citation[1]+'. '+citation[2]+': '+citation[3]+', '+citation[4]+'.')

# %% [markdown]
# We call the function with all the known arguments, and we get our result!

# %%
chicagoCitation('titles.csv', 'All names', 'Title', 'Place of publication', 'Publisher', 'Date of publication')
# Out:
# Evans, Mike. White Punks on Dope. 1977.
# Jones, Steven. No One is Innocent : a punk prayer by Ronald Biggs. 1978.
# Marcus, Greil. In the fascist bathroom : writings on punk 1977-1992. London: Viking, 1993.
# Gibbon, Peter. Of saviours and punks : the political economy of the Nile perch marketing chain in Tanzania. Copenhagen: Centre for Development Research, 1997.
# Butler, Chris. Monkey punk. Hove: Slab-O-Concrete, 1997.
# Mulholland, Garry. This is uncool : the 500 greatest singles since punk and disco. London: Cassell, 2003.
# Wright, Peter Poyntz. Hunky punks : a study in Somerset stone carving. Loughborough: Heart of Albion, 2004.
# Wells, Steven. Anarchy in the UK : the stories behind the anthems of punk. London: Carlton, 2004.
# Jasper, Maura, and Hilken Mancini. Punk rock aerobics : 75 killer moves, 50 punk classics, and 25 reasons to get off your ass and exercise. Cambridge, Massachusetts ; Oxford: Da Capo ; Oxford Publicity Partnership, 2004.
# McGuirk, Niall. Please feed me : a punk vegan cookbook. London ; New York: Soft Skull ; Turnaround, 2004.
# Ercoli, Rikki. Legends of punk : photos from the vault. London ; San Francisco, California: Manic D ; Turnaround, 2003.
# Jocoy, Jim, Thurston  Moore, and Exene Cervenka. We're desperate : the punk photography of Jim Jocoy : SF/LA 78-80. London ; New York: PowerHouse ; Turnaround, 2002.
# Walsh, Gavin. God save the Sex Pistols : a collector's guide to the priests of punk. London: Plexus, 2003.
# King, John. Human punk. London: Jonathan Cape, 2000.
# Cannon, Brian John Matthew. [Going] nowhere : the art and design of the Punk and New Wave movements. London: Omnibus, 1989.
# Bayley, Roberta. Blank generation revisited : the early days of punk rock. London: Omnibus, 1997.
# Bockris, Victor. NYC Babylon : beat punks : notes, raps, essays, secrets, transcripts, opinions (wise and otherwise), and pictures of a gone world and of how the punk generation typhooned its way back through and harpooned the beat generation in harmonica collaboration. London: Omnibus, 1998.
# Rocco, John. The Nirvana companion : two decades of commentary : a chronicle of the end of punk. London: Omnibus, 1998.
# McIver, Joel. Nu-metal : the next generation of rock & punk. London: Omnibus, 2002.
# Anscombe, Isabelle. Not another punk book!. London (27 Floral Street, WC2): Aurum, 1978.
# O'Regan, Denis. Images of punk : musical anarchy that inspired a generation. London: Castle, 1996.
# Belsito, Peter, Bob  Davis, and Marion Kester. Street art : the punk poster in San Francisco 1977-1982. San Francisco: Last Gasp, 1981.
# Leblanc, Lauraine. Pretty in punk : girls' gender resistance in a boys' subculture. New Brunswick, New Jersey: Rutgers University Press, 1999.
# Alexandersson, Gunvor, and Lena Lundquist. Svensk punk / ny våg : musikhistoriskt dokument. Stockholm: L Lundquist, 1981.
# Teipel, Jürgen. Verschwende deine Jugend : ein Doku-Roman über den deutschen Punk und New Wave. Frankfurt am Main: Suhrkamp, 2001.
# Dale, Pete R. W.. Anyone can do it : traditions of punk and the politics of empowerment. : University of Newcastle Upon Tyne, 2010.
# Stewart, Francis Elizabeth. 'Punk rock is my religion' : an exploration of straight edge punk as a surrogate of religion. : University of Stirling, 2011.
# Glasper, Ian. Armed with anger : how UK punk survived the nineties. London: Cherry Red, 2012.
# -. Back on the bins : vegan straight edge hardcore punk zine. 2012.
# Dale, Pete. Anyone can do it : empowerment, tradition and the punk underground. Burlington, Vermont ; Farnham, Surrey: Ashgate, 2012.
# Sanderson, Punk. The mysterious case of Billy's G string. Salisbury, Wiltshire: TheVicar, 2012.
# Bestley, Russell, and Alex Ogg. The art of punk. London: Omnibus, 2012.
# Kerr, Joe, and Andrew Gibson. London from punk to Blair. London: Reaktion, 2012.
# Poulsen, Henrik Bech. 1977 : the year of punk and new wave. London: Soundcheck, 2012.
# Poulsen, Henrik Bech. Nineteen seventy-seven. London: Soundcheck, 2012.
# Ebersole, Stewart Dean, and Jared Castaldi. Barred for life : how Black Flag's iconic logo became punk rock's secret handshake. London ; Oakland, California: Turnaround, 2012.
# Flores, Daniel. Derrumbando la Casa Rosada : mitos y leyendas de los primeros punks en la Argentina, 1978-1988. Buenos Aires, Argentina: Piloto de tormenta, 2011.
# Seven, John, and Jana Christy. Happy Punks 1 2 3 : a counting story. London ; San Francisco, California: Manic D ; Turnaround, 2012.
# Johnson, Mark. Seditious theology : imaginative re-identification, punk and the ministry of Jesus. : University of St Andrews, 2011.
# Mott, Toby. Jubilee, 2012 : Sixty punk singles. Dunstable: Gardners ; KCP ; W+G Australia Ptl ; W+G Australia Ptl, 2012.
# Ensminger, David A.. Left of the dial : conversations with punk icons. London ; Oakland, California: Turnaround, 2012.
# Biel, Joe. Beyond the music : how punks are saving the world with DIY ethics, skills, & values. Lansing, Kansas ; London: Microcosm ; Turnaround, 2012.
# Markey, Dave, and Jordan Schwartz. We got power! : hardcore punk scenes from 1980s Southern California. London ; New York: Bazillion Points ; Turnaround, 2013.
# Harvey, Paul, and University of Northumbria at Newcastle. Stuckism, punk attitude and fine art practice : parallels and similarities. : Northumbria University, 2012.
# Matthews, John, Caitkin  Matthews, and Wil Kinghan. The steam punk tarot : Wisdom from the gods of the machine. London: Weiser ; Brumby Sunstate ; Connections Book ; Grantham Book Services ; New Horizon ; Red Wheel ; United Book, 2012.
# Mitchell, Max. It's just a phase! : a punk rock straight edge vegan zine. Leeds: Footprint Workers' Co-Op, 2012.
# Belk, Martin. Pretty broken punks : lipstick, leather jeans, a death of New York. Edinburgh: Polwarth Publishing LLP, 2012.
# Anniss, Matt. The story of punk and indie. London: Franklin Watts, 2013.
# Singleton, David, Ben Singleton, and Punk Sanderson. The mysterious case of Billy's G string : chronicle the first. Salisbury: TheVicar, 2012.
# Savage, Jon, Stuart Baker, Jamie Reid, and Gee Vaucher. Punk 45 : the singles cover art of punk 1975-80. London: Soul Jazz, 2013.
# Savage, Jon, Stuart Baker, Jamie Reid, and Gee Vauc